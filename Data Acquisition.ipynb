# %% [markdown]
# ## Text Mining CA
# #### This Text mining assignment will focus on job market mining and follow the general steps follows:
# - Data Extraction through web crawler.
# - Text preprocessing.
# - Use the text mining basic methods list the conclusions.
# - Advanced methods to get the findings (word2vec).
#
# In this part, I mainly wrote the web crawler to finish the data extraction, also tried to refine the data for the raw text data.
#
# From https://www.mycareersfuture.sg/, near 220 job results (the website is d) with query about "machine learning" are listed in this sample containing the 12 columns.
#
# Use the <u>BeautifulSoup</u>, <u>selenium</u> to crawler the data in the web page, and also fetch the json data through request apis.
#
# This notebook can be a guideline to show the basic steps.
#
# **Attention!!! Download chromedriver in Method 1, and replace the file path in google_chrome_driver_path in Method 1**

# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import math
import requests
import pandas as pd
import re

# %% [markdown]
# ### Method 1: Use the root url like "https://www.mycareersfuture.sg" to set the query value to get the results

# %%
# need to download the driver support in selenium, refer to below 2 helpers.
# https://selenium-python.readthedocs.io/installation.html#drivers
# https://sites.google.com/a/chromium.org/chromedriver/downloads
google_chrome_driver_path = './chromedriver'
root_url = 'https://www.mycareersfuture.sg'

driver=webdriver.Chrome(google_chrome_driver_path)
driver.get(root_url)
# to wait the page finish loading.
time.sleep(2) 
# find and type in the search bar with "machine learning"
driver.find_element_by_name('search-text').send_keys('machine learning') 
time.sleep(1) 
# find and click the search button
driver.find_element_by_id('search-button').click()
time.sleep(1) 
# now, get the html of all the search result
html = driver.page_source

# %% [markdown]
# ### Method 2: Can just joint the content you wanna query fill in the url:
# see the url like https://www.mycareersfuture.sg/search?search=machine%20learning&sortBy=new_posting_date&page=0
# - set the *search=* equals to your wanted content such as 'machine%20learning', "%20" means the 'space' which is the URL encoding rule, refer to https://zh.wikipedia.org/wiki/%E7%99%BE%E5%88%86%E5%8F%B7%E7%BC%96%E7%A0%81
# - set the *page=* equals to the web pages you wanna jump to. attention the **no result**.

# %%
basic_url = 'https://www.mycareersfuture.sg/search?search=machine%20learning&sortBy=new_posting_date&page={}'
urls = []
# construct 20 pages
for page in range(0, 20):
    query_url = basic_url.format(page)
    urls.append(query_url)
# driver.get(urls[0])
# html = driver.page_source

# %% [markdown]
# ### Start to extract the contents

# %% [markdown]
# #### 1. define the fetch function

# %%
def fetch_data(url, head, payload):
    response = requests.get(url, headers=head, params=payload)
    if response.status_code == 200:
        return response.json()
    else:
        return {'info': 'error', 'error_code': response.status_code}

# %% [markdown]
# #### 2. get the query result number.

# %%
google_chrome_driver_path = '/Users/alexjzy/Desktop/Py-Projects/text_mining/chromedriver'
driver=webdriver.Chrome(google_chrome_driver_path)
query_url = 'https://api.mycareersfuture.sg/jobs?search=machine%20learning&sortBy=new_posting_date'
response = fetch_data(query_url, {}, {})
result_num = math.ceil(response['count']/20)

# %% [markdown]
# #### 3. Since the results showing in the pages, in this part get the total number and the total page

# %%
basic_url = 'https://www.mycareersfuture.sg/search?search=machine%20learning&sortBy=new_posting_date&page={}'
urls = []
# construct 20 pages
for page in range(0, result_num ):
    query_url = basic_url.format(page)
    urls.append(query_url)
print(result_num)
print("urls shape: ", len(urls))
# Out:
# 11
# urls shape:  11

# %%
query_url = 'https://api.mycareersfuture.sg/jobs?search=machine%20learning&sortBy=new_posting_date'
response = fetch_data(query_url, {}, {})
result_num = math.ceil(response['count']/20)

# %%
urls # all the result in pages.
# Out:
# ['https://www.mycareersfuture.sg/search?search=machine%20learning&sortBy=new_posting_date&page=0',
#  'https://www.mycareersfuture.sg/search?search=machine%20learning&sortBy=new_posting_date&page=1',
#  'https://www.mycareersfuture.sg/search?search=machine%20learning&sortBy=new_posting_date&page=2',
#  'https://www.mycareersfuture.sg/search?search=machine%20learning&sortBy=new_posting_date&page=3',
#  'https://www.mycareersfuture.sg/search?search=machine%20learning&sortBy=new_posting_date&page=4',
#  'https://www.mycareersfuture.sg/search?search=machine%20learning&sortBy=new_posting_date&page=5',
#  'https://www.mycareersfuture.sg/search?search=machine%20learning&sortBy=new_posting_date&page=6',
#  'https://www.mycareersfuture.sg/search?search=machine%20learning&sortBy=new_posting_date&page=7',
#  'https://www.mycareersfuture.sg/search?search=machine%20learning&sortBy=new_posting_date&page=8',
#  'https://www.mycareersfuture.sg/search?search=machine%20learning&sortBy=new_posting_date&page=9',
#  'https://www.mycareersfuture.sg/search?search=machine%20learning&sortBy=new_posting_date&page=10']

# %% [markdown]
# #### 4. Use the uuid in every card to get the detail of the job description

# %%
def get_job_description(uuid):
    api_basic = 'https://api.mycareersfuture.sg/job/{}'
    api_jd_url = api_basic.format(uuid)
    json = fetch_data(api_jd_url, {}, {})
    jd = BeautifulSoup(json['job_description']).get_text(strip=True)
    jr = BeautifulSoup(str(json['other_requirements'])).get_text(strip=True)
    jsk = [item['skill'] for item in json['skills']]
    sal_max = json['max_monthly_salary']
    sal_min = json['min_monthly_salary']
    return jd, jr, jsk, sal_max, sal_min

# %% [markdown]
# #### 5. wrap the json return the result.

# %%
def get_detail(card):
    company = card.find("p", {"name": "company"}).get_text()
    job_title = card.find("h1", {"name": "job_title"}).get_text()
    
    # extract the data
    location = card.find_all("p", {"name": "location"})[0].get_text() if len(card.find_all("p", {"name": "location"})) > 0 else None
    employment_type = card.find_all("p", {"name": "employment_type"})[0].get_text() if len(card.find_all("p", {"name": "employment_type"})) > 0 else None
    seniority = card.find_all("p", {"name": "seniority"})[0].get_text() if len(card.find_all("p", {"name": "seniority"})) > 0 else None
    category = card.find_all("p", {"name": "category"})[0].get_text() if len(card.find_all("p", {"name": "category"})) > 0 else None
    
    # get the job detail and collect the jd and requirements which are the raw text
    job_uuid = card.find("a", href=True)['href'].split('-')[-1]
    job_description, job_requirement, job_skills, salary_max, salary_min = get_job_description(job_uuid)
    return {
        "company": company,
        "job_title": job_title,
        "location": location,
        "employment_type": employment_type,
        "seniority": seniority,
        "category": category,
        "job_description": job_description,
        "job_requirement": job_requirement,
        "job_skills": job_skills,
        "job_uuid": job_uuid,
        "salary_min": salary_min,
        "salary_max": salary_max
    }

# %% [markdown]
# #### 6. iterate the card in the cards list.

# %%
def get_card_info(page_url, res):
    driver.get(page_url)
    time.sleep(2)
    html = driver.page_source
    soup = BeautifulSoup(html)
    card_jobs = soup.find("div", {"class": "card-list"})
    cards = card_jobs.find_all("div", {"class": "card relative"})
    for card in cards:
        res.append(get_detail(card))

# %% [markdown]
# #### 7. get the result and convert to dataframe

# %%
result = []
for url in urls:
    get_card_info(url, result)
career_res = pd.DataFrame.from_dict(result)

# %% [markdown]
# ### Start to refine and modify the dataframe

# %%
career_res['job_skills'] = career_res.job_skills.apply(lambda x: ', '.join(x))

# %%
career_res["job_description"] = \
career_res["job_description"].apply(lambda jd:BeautifulSoup(jd).get_text(strip=True))

career_res["job_requirement"] = \
career_res["job_requirement"].apply(lambda x:BeautifulSoup(str(x)).get_text(strip=True))

# %%
career_res["category"] = career_res.category.apply(lambda x:','.join(x.split('/ ')))

# %%
career_res["employment_type"] = career_res.employment_type.apply(lambda x: x.split('...')[0])

# %%
career_res.head()

# %% [markdown]
# #### Save the data to csv.

# %%
career_res.to_csv('mycareersfuture.csv')

# %% [markdown]
# # ——————————————————————————————————
# ### Start to extract the missed job requirements from responsibility

# %%
data = pd.read_csv('mycareersfuture.csv')

# %% [markdown]
# **Fill in the missing job requirements from job descriptions**

# %%
def generate_req_from_des(description):
    if len(re.findall('Requirements', description)) > 0:
        return description.split('Requirements')[-1]
    pattern = re.findall(re.compile('succeed', re.IGNORECASE), description)
    if len(pattern) > 0:
        return description.split(pattern[0])[-1]
    return

# %%
data.loc[data.job_requirement == 'None', 'job_requirement'] = data[data.job_requirement == 'None']['job_description'].apply(lambda des: generate_req_from_des(des))

# %% [markdown]
# **process the long ambigous word, like "ResponsibilitiesWe" to "Responsibilities. We"**

# %%
def pruneLongAmbiguousWord(text):
    def _addFullStop(word):
        wg = word.group()
        indice = [i for i, c in enumerate(wg) if c.isupper()][-1]
        pruned = wg[:indice] + '. ' + wg[indice:]
        return pruned
    pattern = '(?P<word>[A-Z]?[a-z]+[A-Z][a-z]+)'
    return re.sub(pattern, _addFullStop, text)

def trimChar(text):
    text = re.sub(r'[·|\xa0]+', '.', text)
    text = re.sub(r'\.{2}', '.', text)
    if [c for c in text][-1] != '.':
        text = text + '.'
    return text
    
data['job_requirement'] = data['job_requirement'].apply(lambda req: pruneLongAmbiguousWord(str(req)))
data['job_description'] = data['job_description'].apply(lambda des: pruneLongAmbiguousWord(str(des)))

data['job_requirement'] = data['job_requirement'].apply(lambda req: trimChar(str(req)))
data['job_description'] = data['job_description'].apply(lambda des: trimChar(str(des)))

# %%
data.to_csv('./processed_data.csv', index=False)

# %% [markdown]
# ### Mining the specific terms from job requirements such as degree or work experience

# %%
pattern_degree = re.compile(r'Bachelor|Master|PhD|Doctor|Ph.D|Diploma|Masters|BS|MS|BA|master|bachelor|phd|PHD')
pattern_years = re.compile(r'[\d]*[\+]? year[s]? [^.]*[\.|\;]|[one|two|three|four|five|six|seven|eight|nine|ten]* year[s]? [^.]*[\.|\;]')

pattern_years_precise = re.compile(r'[\d]*[\+]? year[s]?\b|[one|two|three|four|five|six|seven|eight|nine|ten]* year[s]?\b')
degree_info = data.job_requirement.apply(lambda req: set(re.findall(pattern_degree, req)))
exp_info = data.job_requirement.apply(lambda req: re.findall(pattern_years, req))
precise = exp_info.apply(lambda exp: re.findall(pattern_years_precise, ''.join([exp[0] for item in exp if exp])))
data['job_experience'] = precise.apply(lambda y: y[0].split(' ')[0] if y else '')
data['job_experience'] = data['job_experience'].apply(lambda year: re.sub('\+', '', year))

def trimDegree(degree):
    if len(degree) == 0: return ''
    newList = []
    for item in degree:
        if item in ['Bachelor', 'BS', 'BA', 'bachelor']:
            newList.append('Bachelor')
        if item in ['Master', 'Masters', 'MS', 'master', 'Msc']:
            newList.append('Master')
        if item in ['PhD', 'Ph.D', 'Doctor', 'phd', 'PHD']:
            newList.append('PhD')
        if item in ['Diploma']:
            newList.append('Diploma')
    dge = ', '.join(set(newList))
    return dge
            
data['job_degree'] = degree_info.apply(lambda x: trimDegree(x))
# Out:
#                            category  \
# 0                   Engineering ...
# 1                   Engineering ...
# 2    Accounting ,Auditing ,Taxation
# 3         Sciences ,Laboratory ,R&D
# 4         Sciences ,Laboratory ,R&D
# 5                   Engineering ...
# 6             Public ,Civil Service
# 7            Information Technology
# 8               Banking and Finance
# 9               Banking and Finance
# 10           Information Technology
# 11              Banking and Finance
# 12           Information Technology
# 13        Sciences ,Laboratory ,R&D
# 14           Information Technology
# 15                      Consulting
# 16           Information Technology
# 17   Healthcare ,Pharmaceutical ...
# 18           Information Technology
# 19              Banking and Finance
# 20        Sciences ,Laboratory ,R&D
# 21              Banking and Finance
# 22        Sciences ,Laboratory ,R&D
# 23              Advertising ,Media
# 24                  Engineering ...
# 25        Sciences ,Laboratory ,R&D
# 26        Sciences ,Laboratory ,R&D
# 27        Sciences ,Laboratory ,R&D
# 28        Sciences ,Laboratory ,R&D
# 29           Information Technology
# ..                              ...
# 186       Sciences ,Laboratory ,R&D
# 187          Information Technology
# 188          Information Technology
# 189          Information Technology
# 190             Banking and Finance
# 191                     Engineering
# 192                 Engineering ...
# 193                          Others
# 194          Information Technology
# 195                     Engineering
# 196          Information Technology
# 197                     Engineering
# 198       Sciences ,Laboratory ,R&D
# 199          Education and Training
# 200          Education and Training
# 201                      Design ...
# 202          Information Technology
# 203             Advertising ,Media
# 204       Sciences ,Laboratory ,R&D
# 205    Marketing ,Public Relations
# 206    Marketing ,Public Relations
# 207    Marketing ,Public Relations
# 208      Education and Training ...
# 209          Information Technology
# 210           Public ,Civil Service
# 211      Information Technology ...
# 212      Information Technology ...
# 213       Environment ,Health   ...
# 214      Education and Training ...
# 215      Education and Training ...
#
#                                                company employment_type  \
# 0                               PROPERTYGURU PTE. LTD.      Permanent
# 1                               PROPERTYGURU PTE. LTD.      Permanent
# 2                     ERNST & YOUNG ADVISORY PTE. LTD.      Permanent
# 3                             A*STAR RESEARCH ENTITIES       Contract
# 4                             A*STAR RESEARCH ENTITIES       Contract
# 5                                  Company Undisclosed      Permanent
# 6           Smart Nation and Digital Government Office       Full Time
# 7                           SCHELLDEN GLOBAL PTE. LTD.       Full Time
# 8                                  Company Undisclosed       Full Time
# 9                                  Company Undisclosed       Full Time
# 10                             SINGAPORE POWER LIMITED       Permanent
# 11         IT CONSULTING SOLUTIONS SINGAPORE PTE. LTD.        Contract
# 12               CHARLES & KEITH (SINGAPORE) PTE. LTD.       Full Time
# 13                    NANYANG TECHNOLOGICAL UNIVERSITY       Contract
# 14                         DEEP MIND CAPITAL PTE. LTD.       Full Time
# 15                                 Company Undisclosed       Full Time
# 16                                HANALYTICS PTE. LTD.      Permanent
# 17                              Health Promotion Board       Permanent
# 18                         GRABTAXI HOLDINGS PTE. LTD.       Full Time
# 19                MORGAN STANLEY ASIA (SINGAPORE) PTE.       Full Time
# 20                    NATIONAL UNIVERSITY OF SINGAPORE       Contract
# 21                                       CITIBANK N.A.       Full Time
# 22                            A*STAR RESEARCH ENTITIES       Contract
# 23                                 Company Undisclosed       Full Time
# 24                               RESMED ASIA PTE. LTD.      Permanent
# 25                    NANYANG TECHNOLOGICAL UNIVERSITY       Contract
# 26                    NANYANG TECHNOLOGICAL UNIVERSITY       Contract
# 27                            A*STAR RESEARCH ENTITIES       Contract
# 28                            A*STAR RESEARCH ENTITIES       Contract
# 29                                    CAPITA PTE. LTD.       Full Time
# ..                                                 ...             ...
# 186                           A*STAR RESEARCH ENTITIES       Contract
# 187                        PALO IT SINGAPORE PTE. LTD.      Permanent
# 188                          DATHENA SCIENCE PTE. LTD.      Permanent
# 189                         SINGAPORE AIRLINES LIMITED       Permanent
# 190                             AXA DIL@ASIA PTE. LTD.       Full Time
# 191                   NANYANG TECHNOLOGICAL UNIVERSITY       Contract
# 192  CAMBRIDGE CENTRE FOR ADVANCED RESEARCH AND EDU...       Full Time
# 193                   NATIONAL UNIVERSITY OF SINGAPORE       Contract
# 194                           KKT TECHNOLOGY PTE. LTD.       Full Time
# 195        GLOBAL FASHION GROUP SGP SERVICES PTE. LTD.       Full Time
# 196                                Company Undisclosed       Full Time
# 197                         DYSON OPERATIONS PTE. LTD.      Permanent
# 198                   NANYANG TECHNOLOGICAL UNIVERSITY       Contract
# 199                    SINGAPORE MANAGEMENT UNIVERSITY       Full Time
# 200                    SINGAPORE MANAGEMENT UNIVERSITY       Full Time
# 201                      PEACH INTELLIHEALTH PTE. LTD.       Full Time
# 202                           CPM CONSULTING PTE. LTD.       Permanent
# 203        DENTSU AEGIS NETWORK ASIA PACIFIC PTE. LTD.      Permanent
# 204                   NANYANG TECHNOLOGICAL UNIVERSITY       Contract
# 205                 BIPO SERVICE (SINGAPORE) PTE. LTD.       Full Time
# 206                 BIPO SERVICE (SINGAPORE) PTE. LTD.       Full Time
# 207                 BIPO SERVICE (SINGAPORE) PTE. LTD.       Full Time
# 208                                PBA SYSTEMS PTE LTD       Permanent
# 209                                Company Undisclosed       Permanent
# 210                            Public Service Division       Full Time
# 211                       GOVERNMENT TECHNOLOGY AGENCY       Permanent
# 212                       GOVERNMENT TECHNOLOGY AGENCY       Full Time
# 213                             Health Promotion Board       Full Time
# 214                               Republic Polytechnic        Contract
# 215                               Republic Polytechnic        Contract
#
#                                        job_description  \
# 0    Our websites attract more than 100 million mon...
# 1    Our websites attract more than 100 million mon...
# 2    Join Fraud Investigation & Dispute Services (F...
# 3    The Agency for Science, Technology and Researc...
# 4    Specialize in applying data analytics, machine...
# 5    About The Role. As IAG focuses on creating an ...
# 6    The Smart Nation and Digital Government Office...
# 7    You will be responsible for end to end develop...
# 8    . Lead the definition of activities, scope, an...
# 9    . Lead the definition of activities, scope, an...
# 10   Roles & Responsibilities. Why Work for Us. We ...
# 11   Our client is an investment holding company. T...
# 12   Job Responsibilities. Align, understand and pr...
# 13   The Rapid-Rich Object SEarch (ROSE) Lab is a j...
# 14   Deep Mind.Capital is a digital asset managemen...
# 15   Interested applicant please apply via this lin...
# 16   Who Will Impress UsA strong technical individu...
# 17   Assistant Director, Data Science. Overview of ...
# 18   Get to know the Role:Report into the Data Scie...
# 19   Company Profile. Morgan Stanley is a leading g...
# 20   The RA will be responsible to come up with new...
# 21   Job Purpose:The charter of this role is to pro...
# 22   About the Institute of High Performance Comput...
# 23   We are considering candidates for both junior ...
# 24   Data Scientist. We are currently seeking appli...
# 25   The Institute for Media Innovation ( http://im...
# 26   The Institute for Media Innovation ( http://im...
# 27   The candidate will perform both fundamental re...
# 28   The candidate will perform both fundamental re...
# 29   Solves complex technical problem/solution.Cons...
# ..                                                 ...
# 186  The Agency for Science, Technology and Researc...
# 187  Your profile & role on the projectYOU:Thrive o...
# 188  Job Purpose. We are looking for an AI and Mach...
# 189  SIA has implemented the Enterprise Information...
# 190  The AXA Group, a worldwide leader in Insurance...
# 191  The School of Civil and Environmental Engineer...
# 192  Who are we looking for?The project aims at a c...
# 193  Develop software as a part of a young, dynamic...
# 194  Responsibilities. Develop predictive models on...
# 195  Global Fashion Group (“GFG”) is the #1 online ...
# 196  Daimler Financial Services is headquartered in...
# 197  Design and implement machine learning applicat...
# 198  Established in 1981, the SCHOOL OF ELECTRICAL ...
# 199  (1) Analytics(a) Capable of designing and deli...
# 200  (1) Analytics(a) Capable of designing and deli...
# 201  Responsibilities. Interact with business, tech...
# 202  Primary Responsibilities:Understand large data...
# 203  Background. The i. Prospect global product tea...
# 204  The candidate is expected to design and implem...
# 205  Our Client's Company background: Byte. Mod (al...
# 206  Our Client's Company background: Byte. Mod (al...
# 207  Our Client's Company background: Byte. Mod (al...
# 208  RACE Academy (http://raceacademy.com.sg) is a ...
# 209  Profile:Create value by challenging the status...
# 210  The Smart Nation and Digital Government Office...
# 211  We are seeking a Development Lead to take on t...
# 212  BAF (Data Analytics)We are looking for Busines...
# 213  Strategy and Industry Engagement lead, Technol...
# 214  Responsibilities. We are looking for a respons...
# 215  Job Responsibilities. We are looking for a cap...
#
#                                        job_requirement  \
# 0    Bachelor’s degree in IT or relevant field. Alt...
# 1    Bachelor’s degree in IT or relevant field. Alt...
# 2    To qualify for the role you must have. Strong ...
# 3    Bachelor or Master's Degree in physical scienc...
# 4    PhD in Power System operation and analysis or ...
# 5    These are the skills and experience we are loo...
# 6    We are in search of motivated individuals who ...
# 7    What you have done: Commercial software engin...
# 8    Knowledge in at least 1 of the following data ...
# 9    Knowledge in at least 1 of the following data ...
# 10   Requirements. What You'll Need. We are looking...
# 11   -. At least 1 year hands-on experience in crit...
# 12   Requirement. At least a Degree or Masters in M...
# 13   Bachelor degree in Computer Science, Electrica...
# 14   Bachelor’s degree with 3 years minimum experie...
# 15   Must have deep hands-on.experience with On-pre...
# 16   The Candidate. Our aim is to align you with th...
# 17   . Qualification or work experience in data sci...
# 18   he must haves:Ph.D. graduate, or Masters(with ...
# 19   Skills Required2+ years of experience. Educati...
# 20   Advanced Skills in current Machine Learning Te...
# 21   The ideal candidate will meet the following re...
# 22   PhD degree in Computer Science/Engineering wit...
# 23   Requirements:Bachelor’s, Master’s or PhD degre...
# 24   Let’s talk about you:To really get us excited,...
# 25   The candidates should hold a Doctorate degree ...
# 26   The candidates should hold a Master degree fro...
# 27   PhD in Computer Science/Engineering with exper...
# 28   PhD in Computer Science/Engineering with exper...
# 29   Must have experience in large-scale projects/p...
# ..                                                 ...
# 186  Degree holder in computer science, EEE or mech...
# 187  You hold a Bachelor, Master or PhD degree in C...
# 188  Skills and Qualifications2+ years experience i...
# 189  BS in Computer Science or other related discip...
# 190  Successful qualifier of this mission:Professio...
# 191  Master degree in Computer Science, Computer En...
# 192  What skills do you have?A PhD degree in a rele...
# 193  Postgraduate university degree in IT, science ...
# 194  Requirements. Minimum. Deep understanding of s...
# 195  Your Skills and Experience:Having a Ph.D. or M...
# 196  • Degree in Computer Science, Mathematics, Phy...
# 197  Strong quantitative background; a master degre...
# 198  Master degree in Electrical and Computer Engin...
# 199  (1) We are continually on the lookout for outs...
# 200  (1) We are continually on the lookout for outs...
# 201  Quantitative background with advanced degree(s...
# 202  Candidate should possess good soft skills as m...
# 203  SKILLS REQUIREDExperience in marketing big dat...
# 204  Required qualifications:A Bachelor’s degree in...
# 205  BA/BS degree in marketing, advertising, techno...
# 206  Bachelor’s degree is required.Minimum 3 years ...
# 207  Bachelor’s degree;5+ years work experience in ...
# 208  A degree in electrical/electronic/computer eng...
# 209  Job Requirements:Bachelor's degree in Computer...
# 210  We are in search of motivated individuals who ...
# 211  :Degree or Diploma in Computer Science, Comput...
# 212  :Degree/Master in any discipline; Diploma grad...
# 213                                              None.
# 214  Skills and Experience:•.Qualifications in Comp...
# 215  • At least a Bachelor’s Degree in Computer Sci...
#
#                                             job_skills  \
# 0    Data Analysis, SQL, Microsoft Excel, Microsoft...
# 1    Data Analysis, SQL, Microsoft Excel, Microsoft...
# 2    Accounting, Microsoft Excel, Microsoft Word, G...
# 3    Matlab, Algorithms, C++, Machine Learning, C, ...
# 4    R&D, Molecular Biology, Biotechnology, Lifesci...
# 5    Analytics, Data Analysis, Analysis, Statistica...
# 6    Human Resources, Employee Relations, Recruitin...
# 7    Engineering, Project Management, Testing, Soft...
# 8    Management, Leadership, Strategy, Strategic Pl...
# 9    Management, Leadership, Strategy, Strategic Pl...
# 10   Linux, Windows Server, Microsoft SQL Server, M...
# 11   JavaScript, SQL, Java, XML, Microsoft SQL Serv...
# 12   Databases, Microsoft SQL Server, SQL, Business...
# 13   Research, Matlab, Data Analysis, C++, Microsof...
# 14   Management, Leadership, Project Management, St...
# 15   Architecture, Architectural Design, Sustainabl...
# 16   Algorithms, Software Engineering, Computer Sci...
# 17   Analytics, Data Analysis, Analysis, Statistica...
# 18   Algorithms, Software Engineering, Computer Sci...
# 19   Management, Strategy, Leadership, Microsoft Of...
# 20   Research, Matlab, Data Analysis, C++, Microsof...
# 21   Business Analysis, Project Management, Managem...
# 22   R&D, Molecular Biology, Biotechnology, Lifesci...
# 23   Databases, Microsoft SQL Server, SQL, Business...
# 24   R&D, Molecular Biology, Biotechnology, Lifesci...
# 25   Research, Science, Matlab, LaTeX, Algorithms, ...
# 26   Research, Data Analysis, Matlab, Molecular Bio...
# 27   Matlab, Algorithms, C++, Machine Learning, C, ...
# 28   R&D, Molecular Biology, Biotechnology, Lifesci...
# 29   Management, Project Management, Strategy, Lead...
# ..                                                 ...
# 186  Matlab, Algorithms, C++, Machine Learning, C, ...
# 187  Analytics, Data Analysis, Analysis, Statistica...
# 188  Java, JavaScript, Software Development, C++, L...
# 189  Databases, SQL, Microsoft SQL Server, MySQL, D...
# 190  Data Management, Management, Databases, Micros...
# 191  Research, Data Analysis, Matlab, Molecular Bio...
# 192  Algorithms, Software Engineering, Computer Sci...
# 193  Research, Science, Matlab, LaTeX, Algorithms, ...
# 194  Market Research, Quantitative Research, Manage...
# 195  Engineering, Project Management, Testing, Matl...
# 196  Data Warehousing, Data Modeling, Business Inte...
# 197  Java, JavaScript, Software Development, C++, L...
# 198  Research, Data Analysis, Matlab, Molecular Bio...
# 199  Research, Teaching, Higher Education, Universi...
# 200  Research, Teaching, Higher Education, Universi...
# 201  Art, Photoshop, Drawing, Painting, Maya, Illus...
# 202  Management, Project Management, Strategy, Lead...
# 203  Cloud Computing, Integration, Pre-sales, Telec...
# 204  Matlab, Algorithms, C++, Machine Learning, C, ...
# 205  Marketing, Marketing Strategy, Marketing Commu...
# 206  Marketing, Marketing Strategy, Management, Sal...
# 207  Corporate Communications, Public Relations, Ma...
# 208  Engineering, Mechanical Engineering, Solidwork...
# 209  Solution Architecture, Cloud Computing, Integr...
# 210  Human Resources, Recruiting, Employee Relation...
# 211  Java, SharePoint, Software Development, Active...
# 212  Business Analysis, Project Management, Managem...
# 213  Management, Project Planning, Strategic Planni...
# 214  Matlab, Algorithms, C++, Machine Learning, C, ...
# 215  Statistics, Operations Research, Data Analysis...
#
#                                              job_title  \
# 0                                        Data Engineer
# 1                                        Data Engineer
# 2    Fraud Investigation & Dispute Services (FIDS) ...
# 3    Research Engineer / Senior Research Engineer (...
# 4             Scientist (Power System Analytics), EPGC
# 5                                       Data Scientist
# 6     Manager  /  Senior Manager (Talent and Manpower)
# 7                             senior big data engineer
# 8    Vice President, Portfolio & Regulatory Managem...
# 9    Vice President, Portfolio & Regulatory Managem...
# 10              Data Engineer  /  Senior Data Engineer
# 11              Application Production Support Analyst
# 12                                 Senior Data Analyst
# 13                                     Project Officer
# 14                                     Product Manager
# 15                                           Architect
# 16                           Machine Learning Engineer
# 17                    Assistant Director, Data Science
# 18                                      Data Scientist
# 19   Technology - Fusion Cyber Analytics Research a...
# 20                                  Research Assistant
# 21           GCG - Business Analyst Manager - 17053710
# 22                                    Scientist (IHPC)
# 23                    Data Scientist, APAC (Singapore)
# 24                                      Data Scientist
# 25                                     Research Fellow
# 26                                  Research Associate
# 27                                   Research Engineer
# 28                                           Scientist
# 29                                          Consultant
# ..                                                 ...
# 186  Research Engineer / Senior Research Engineer (...
# 187          Senior Analytics Manager - Data Scientist
# 188                                     Data Scientist
# 189                 Data Sciences & Analytics Engineer
# 190                              Data Science Engineer
# 191                                 Research Associate
# 192                                 Computer Scientist
# 193  Programmer for scientific image processing (Re...
# 194                                     Data Scientist
# 195                               GFG - Data Scientist
# 196  Assistant Manager - Data Science and Architecture
# 197                         Advanced Software Engineer
# 198                                 Research Associate
# 199  SIS - Associate Professor of Information Syste...
# 200  SIS - Assistant Professor of Information Syste...
# 201  Scientist  /  Senior Scientist, Artificial Int...
# 202                            Data Science Consultant
# 203                          Global Solutions Engineer
# 204                                  Research Engineer
# 205                                   Ad Sales Manager
# 206                        Marketing Operation Manager
# 207                          International PR Director
# 208                                   Robotic Engineer
# 209                                 Solution architect
# 210   Manager  /  Senior Manager (Talent and Manpower)
# 211  Development Lead (Assistant Director / Deputy ...
# 212                  Business Analyst (Data Analytics)
# 213  Senior Deputy Director  /  Deputy Director, Te...
# 214  School of Infocomm - Research Staff (Text Anal...
# 215  School of Infocomm - Research Staff (Data Anal...
#
#                              job_uuid    location  salary_max  \
# 0    82e462a13cadc477f93d57ad6812d1d1     Central      7000.0
# 1    763708ca5a581db4389a766ef71654a0     Central      9000.0
# 2    c59d6037f441a5b3b43ca4daff84806a     Central     16000.0
# 3    cec1905d6444838c2d7108c1a04049a3        West      5000.0
# 4    d2da04bb4033006cb580fc80e752fa9e        West     11800.0
# 5    972f2d0cd68c45fbf7d50920fc229036     Central     12000.0
# 6    cb3cb0fd4276956c30baab4084802b3a         NaN         0.0
# 7    6b9679d4563c270b58f3a9a89638564a  Islandwide      7000.0
# 8    e11a65ce7a59ca9f6a19bcf76c62ac68     Central     10000.0
# 9    dda2dea97c28a907fe2b7ee0346d4e77     Central     10000.0
# 10   4cd668c50a85ba02abd424a650a92136        East      8000.0
# 11   b10133c8d371d4dfe1de39400b5155f1       South      8000.0
# 12   6659d599806e295ca7bb79a243adb38b     Central      5000.0
# 13   0fad24b00ab6d9df9bdf41781f7b084a        West      4500.0
# 14   8c9fe53d59f2e9098b7dbd3c278b7fea     Central      8000.0
# 15   2b6342a137ded6093c9618d72f3155bf     Central     12500.0
# 16   7642a78635193da3ad8204a34daaf181     Central      5000.0
# 17   d2d8e6c23fb3649e7b224cbb6501b4cc         NaN         0.0
# 18   2a2ee56c3b3cec5ccff768b099f09fe1     Central     14500.0
# 19   bc3a4aa861e468e4cd232d59ccd5d256     Central     10000.0
# 20   9937de616b75ce1698384867975501d7       South      4000.0
# 21   3f3fe91fe7c5940b1ecc80f387d5ab14     Central     17500.0
# 22   dec9b53ccd64af7027d4cd08f3146992       South      9000.0
# 23   7a4299c3536619c564293048bea1cce1     Central     12000.0
# 24   2f0c26cd85b0964482421f8d9f7ec3bd       South      7000.0
# 25   913340be62541afd2571365b5eff0cf6        West      6500.0
# 26   5765a6d1b881d9536bcd64108f1d9b35        West      4000.0
# 27   31decfaf2092d81406301e735b1b8bdd       South      9000.0
# 28   cfe404cfd5e11fa12c61fa2d8d295bc7       South      9000.0
# 29   b798203ef1c4878b8ae6a0d38bef92fd        East      7000.0
# ..                                ...         ...         ...
# 186  d86d955368b41b2a543e1530bbe0269b        West      5000.0
# 187  3e0e537665209844cc7d4a32226f72ab     Central     12000.0
# 188  1312535ac143e9d7adadf7b1b67de06f        East      8000.0
# 189  91dfb5cd8304de2a385abcc64d798447        East      8000.0
# 190  63f272076a30b65095cc525f157f75f6     Central      5500.0
# 191  26a431ed77f4b3731d6827d8e0a261e8        West      3900.0
# 192  88752d547c94b04fd687d0a219e08948       South      9000.0
# 193  5d0685928fe7f8b10a586bb9e5cc4dea       South      6000.0
# 194  b325262b317035bca49c7c1983aaa144     Central      6200.0
# 195  8cc8f32b769bf4c78f63416d33f3855d     Central         NaN
# 196  15f94d0fb1d37ec49dcd011c504b746c        West      9000.0
# 197  0b1730faa83a9206c2c35b63e4018669  Islandwide      7500.0
# 198  de2c4fe319aaf7f9c98c514375415d7d        West      3800.0
# 199  a29402724a5dee58dd9e1868bb0223b1        East     20000.0
# 200  d05f18a2a92c3f5753a702058b8dead8        East     16000.0
# 201  282d8d7b999aa39cd49b8cadece1d298       South      7500.0
# 202  0a2a428522865a7fe47e40bdf563a6e6     Central      6500.0
# 203  d76ee47060586c49d4da5c9250da7f86     Central     13000.0
# 204  db520a7ed727d61d4e5f67b3b17fa27e        West      3850.0
# 205  8bb0f29ef4ec85d966db197e05aa67da  Islandwide     15000.0
# 206  6bda14d1b85d52eebb61338bce7b7a7b  Islandwide     12500.0
# 207  e37741199a4a9355511d41607df9dc5b  Islandwide     15000.0
# 208  2de35beaa36d164f9ea115cb88e35508       North      5200.0
# 209  41f6a7860a3f589ead027585ac65d574       South      6800.0
# 210  f01ff9fc64cb143fde616b8d97709616         NaN         0.0
# 211  bf0bfb2cfbc8208786d76ae0aa4bb1b9         NaN         0.0
# 212  9e6bb89686d7ae65bd6554890fd0ea0d         NaN         0.0
# 213  da6ff054ba8acee46b7ce3e5adb96e44         NaN         0.0
# 214  bdb3a8b22365e72310e2edc0fbfc737a         NaN         0.0
# 215  2dfa82ed3e823b2277f19dbd1538fc5d         NaN      5300.0
#
#              ...                                           job_requirement_nn  \
# 0            ...            ['Bachelor', '’', 'degree', 'IT', 'field', 'qu...
# 1            ...            ['Bachelor', '’', 'degree', 'IT', 'field', 'qu...
# 2            ...            ['role', 'record', 'degree', 'field', 'years',...
# 3            ...            ['Bachelor', 'Master', 'Degree', 'sciences', '...
# 4            ...            ['PhD', 'Power', 'System', 'operation', 'analy...
# 5            ...            ['skills', 'experience', 'Experience', 'manipu...
# 6            ...            ['search', 'individuals', 'share', 'traits', '...
# 7            ...            ['Commercial', 'software', 'engineering', '.Yo...
# 8            ...            ['Knowledge', 'data', 'science', 'domains', 'T...
# 9            ...            ['Knowledge', 'data', 'science', 'domains', 'T...
# 10           ...            ['Requirements', 'Passion', 'Proficiency', 'Go...
# 11           ...            ['year', 'experience', 'production', 'support....
# 12           ...            ['Requirement', 'Degree', 'Masters', 'Mathemat...
# 13           ...            ['Bachelor', 'degree', 'Computer', 'Science', ...
# 14           ...            ['Bachelor', '’', 'degree', 'years', 'experien...
# 15           ...            ['Must', 'hands-on.experience', 'On-prem', 'Cl...
# 16           ...            ['Candidate', 'aim', 'activities', 'interest',...
# 17           ...            ['Qualification', 'work', 'experience', 'data'...
# 18           ...            ['Ph.D.', 'graduate', 'Masters', 'years', 'exp...
# 19           ...            ['Skills', 'Required2+', 'years', 'experience'...
# 20           ...            ['Advanced', 'Skills', 'Machine', 'Learning', ...
# 21           ...            ['candidate', 'requirements', 'Business', 'Pro...
# 22           ...            ['PhD', 'degree', 'Computer', 'expertise', 'Ma...
# 23           ...            ['Requirements', 'Bachelor', '’', 's', 'Master...
# 24           ...            ['’', 'talk', 'knowledge', 'machine', 'theorie...
# 25           ...            ['candidates', 'Doctorate', 'degree', 'Univers...
# 26           ...            ['candidates', 'Master', 'degree', 'University...
# 27           ...            ['PhD', 'Computer', 'expertise', 'Machine', 'L...
# 28           ...            ['PhD', 'Computer', 'expertise', 'Machine', 'L...
# 29           ...            ['Must', 'experience', 'projects/programs', 'I...
# ..           ...                                                          ...
# 186          ...            ['Degree', 'holder', 'computer', 'science', 'E...
# 187          ...            ['Bachelor', 'Master', 'PhD', 'Computer', 'Sci...
# 188          ...            ['Skills', 'Qualifications2+', 'years', 'exper...
# 189          ...            ['BS', 'Computer', 'Science', 'discipline', 'A...
# 190          ...            ['qualifier', 'mission', 'Professional', 'skil...
# 191          ...            ['Master', 'degree', 'Computer', 'Science', 'C...
# 192          ...            ['PhD', 'degree', 'discipline', 'mathematics',...
# 193          ...            ['Postgraduate', 'university', 'degree', 'IT',...
# 194          ...            ['Requirements', 'Minimum', 'Deep', 'understan...
# 195          ...            ['Skills', 'Experience', 'Ph.D.', 'Masters', '...
# 196          ...            ['Degree', 'Computer', 'Science', 'Mathematics...
# 197          ...            ['background', 'master', 'degree', 'Computer',...
# 198          ...            ['Master', 'degree', 'Electrical', 'Computer',...
# 199          ...            ['lookout', 'faculty', 'candidates', 'levels',...
# 200          ...            ['lookout', 'faculty', 'candidates', 'levels',...
# 201          ...            ['background', 'degree', 's', 'majors', 'Compu...
# 202          ...            ['Candidate', 'skills', 'problem', 'solving', ...
# 203          ...            ['SKILLS', 'REQUIREDExperience', 'data', 'solu...
# 204          ...            ['qualifications', 'Bachelor', '’', 'degree', ...
# 205          ...            ['BA/BS', 'degree', 'marketing', 'advertising'...
# 206          ...            ['Bachelor', '’', 's', 'degree', 'years', 'exp...
# 207          ...            ['Bachelor', '’', 'degree', 'years', 'experien...
# 208          ...            ['degree', 'electrical/electronic/computer', '...
# 209          ...            ['Job', 'Requirements', 'Bachelor', 'degree', ...
# 210          ...            ['search', 'individuals', 'share', 'traits', '...
# 211          ...            ['Degree', 'Diploma', 'Computer', 'Science', '...
# 212          ...            ['Degree/Master', 'discipline', 'Diploma', 'ex...
# 213          ...                                                     ['None']
# 214          ...            ['Skills', 'Experience', '•.Qualifications', '...
# 215          ...            ['•', 'Bachelor', '’', 'Degree', 'Computer', '...
#
#                                     job_description_nn  \
# 0    ['websites', 'page-views', 'click-stream', 'be...
# 1    ['websites', 'page-views', 'click-stream', 'be...
# 2    ['Join', 'Fraud', 'Investigation', 'Dispute', ...
# 3    ['Agency', 'Science', 'Technology', 'Research'...
# 4    ['Specialize', 'data', 'analytics', 'machine',...
# 5    ['Role', 'IAG', 'organisation', 'Data', 'Scien...
# 6    ['Smart', 'Nation', 'Digital', 'Government', '...
# 7    ['end', 'development', 'Data', 'Analytics', 'u...
# 8    ['definition', 'activities', 'scope', 'timelin...
# 9    ['definition', 'activities', 'scope', 'timelin...
# 10   ['Roles', 'Responsibilities', 'Work', 'Us', 'N...
# 11   ['client', 'investment', 'company', 'Applicati...
# 12   ['Job', 'Responsibilities', 'Align', 'understa...
# 13   ['Object', 'SEarch', 'ROSE', 'Lab', 'research'...
# 14   ['Mind.Capital', 'asset', 'management', 'compa...
# 15   ['please', 'link', '.https', '//careers.micros...
# 16   ['Impress', 'UsA', 'individual', 'geeky', 'bac...
# 17   ['Assistant', 'Director', 'Data', 'Science', '...
# 18   ['Role', 'Report', 'Data', 'Science', 'Dept', ...
# 19   ['Company', 'Profile', 'Morgan', 'Stanley', 's...
# 20   ['RA', 'approaches', 'machine', 'recognition',...
# 21   ['Job', 'Purpose', 'charter', 'role', 'thought...
# 22   ['Institute', 'High', 'Performance', 'Computin...
# 23   ['candidates', 'positions.Who', 'Data', 'Scien...
# 24   ['Data', 'Scientist', 'applications', 'Data', ...
# 25   ['Institute', 'Media', 'Innovation', 'http', '...
# 26   ['Institute', 'Media', 'Innovation', 'http', '...
# 27   ['candidate', 'research', 'research', 'area', ...
# 28   ['candidate', 'research', 'research', 'area', ...
# 29   ['Solves', 'problem/solution.Consult', 'design...
# ..                                                 ...
# 186  ['Agency', 'Science', 'Technology', 'Research'...
# 187  ['profile', 'role', 'projectYOU', 'Thrive', 'c...
# 188  ['Job', 'Purpose', 'AI', 'Machine', 'Learning'...
# 189  ['SIA', 'Enterprise', 'Information', 'Manageme...
# 190  ['AXA', 'Group', 'leader', 'Insurance', 'Asset...
# 191  ['School', 'Civil', 'Environmental', 'Engineer...
# 192  ['project', 'virtualisation', 'park', 'i.e', '...
# 193  ['Develop', 'software', 'part', 'start-up', 'n...
# 194  ['Responsibilities', 'Develop', 'models', 'hea...
# 195  ['Fashion', 'Group', '“', 'GFG', '”', 'fashion...
# 196  ['Daimler', 'Financial', 'Services', 'Singapor...
# 197  ['Design', 'machine', 'application', 'products...
# 198  ['SCHOOL', 'OF', 'ELECTRICAL', 'AND', 'ELECTRO...
# 199  ['Analytics', 'Capable', 'level', 'courses', '...
# 200  ['Analytics', 'Capable', 'level', 'courses', '...
# 201  ['Responsibilities', 'Interact', 'business', '...
# 202  ['Responsibilities', 'Understand', 'data', 'se...
# 203  ['Background', 'i', 'Prospect', 'product', 'te...
# 204  ['candidate', 'machine-learning', 'techniques'...
# 205  ['Client', 'Company', 'background', 'Byte', 'M...
# 206  ['Client', 'Company', 'background', 'Byte', 'M...
# 207  ['Client', 'Company', 'background', 'Byte', 'M...
# 208  ['RACE', 'Academy', 'http', '//raceacademy.com...
# 209  ['Profile', 'Create', 'value', 'status', 'quo'...
# 210  ['Smart', 'Nation', 'Digital', 'Government', '...
# 211  ['Development', 'Lead', 'exciting', 'role', 'd...
# 212  ['BAF', 'Data', 'Analytics', 'Business', 'Anal...
# 213  ['Strategy', 'Industry', 'Engagement', 'lead',...
# 214  ['Responsibilities', 'individual', 'industry',...
# 215  ['Job', 'Responsibilities', 'individual', 'R',...
#
#                                    job_requirement_nnp  \
# 0    ['Bachelor', '’', 'IT', 'SQL', 'Azkaban', 'Air...
# 1    ['Bachelor', '’', 'IT', 'SQL', 'Azkaban', 'Air...
# 2    ['Life', 'Science', 'Ability', 'English', 'EY'...
# 3           ['Bachelor', 'Master', 'Degree', 'A*STAR']
# 4    ['PhD', 'Power', 'System', 'Computer', 'Knowle...
# 5    ['SQL', 'Python', 'Gigabytes', 'Py', 'Spark', ...
# 6    ['Value', 'Singapore', 'Strong', 'Excellent', ...
# 7    ['Commercial', 'Java', 'Python', 'Py', 'Spark'...
# 8    ['Knowledge', 'Text', 'Mining', '/', 'NLPGraph...
# 9    ['Knowledge', 'Text', 'Mining', '/', 'NLPGraph...
# 10   ['Passion', 'Proficiency', 'Good', 'Java', 'Py...
# 11   ['Bachelor', '’', 'Strong', 'Unix/Linux', 'SQL...
# 12   ['Degree', 'Masters', 'Mathematics', 'Economic...
# 13   ['Bachelor', 'Computer', 'Science', 'Electrica...
# 14   ['Bachelor', '’', 'Business', 'Finance', 'IT',...
# 15   ['Must', 'On-prem', 'Cloud', 'AWS', 'Hadoop/Sp...
# 16   ['Candidate', '/', 'C++', 'RNN', 'CNN', 'Educa...
# 17   ['R', 'Python', 'SQL', 'Proven', 'Possess', 'R...
# 18   ['Ph.D.', 'Computer', 'Science', '.Electrical/...
# 19   ['Skills', 'Required2+', 'Computer', 'Science'...
# 20   ['Advanced', 'Skills', 'Machine', 'Learning', ...
# 21   ['Product', 'Knowledge', 'Strong', 'Decision',...
# 22   ['PhD', 'Computer', 'Machine', 'Learning', 'C+...
# 23   ['Bachelor', '’', 'Master', '’', 'PhD', 'Compu...
# 24   ['’', 'SQL', 'Masters', 'PhD', 'Degree', 'Data...
# 25   ['Doctorate', 'University', 'Interactive', 'Di...
# 26   ['Master', 'University', 'Interactive', 'Digit...
# 27   ['Computer', 'Machine', 'Learning', 'Optimizat...
# 28   ['Computer', 'Machine', 'Learning', 'Optimizat...
# 29   ['Must', 'IT/Digital', 'Transformation', 'Clou...
# ..                                                 ...
# 186  ['Degree', 'EEE', 'Minimum', 'Skillful', 'A*ST...
# 187  ['Bachelor', 'Master', 'PhD', 'Computer', 'Sci...
# 188  ['Qualifications2+', 'Spark', 'Scala/Python/Ap...
# 189  ['BS', 'Computer', 'Science', 'Advanced', 'Mac...
# 190  ['Professional', 'Bachelor', 'Master', '’', 'D...
# 191  ['Master', 'Computer', 'Science', 'Computer', ...
# 192  ['PhD', 'CREATE', 'Tower', 'NUS', 'University'...
# 193  ['Postgraduate', 'IT', 'R', 'D', 'Excellent', ...
# 194  ['Minimum', 'Deep', 'Python', 'R', 'Python', '...
# 195  ['Ph.D.', 'Masters', 'Degree', 'Computer', 'Sc...
# 196  ['Degree', 'Computer', 'Science', 'Mathematics...
# 197  ['Computer', 'Science', 'Mathematics', 'Statis...
# 198  ['Master', 'Electrical', 'Computer', 'Engineer...
# 199  ['Ph.D.s-', 'Postdocs', 'Ph.D.s', 'Highly', 'M...
# 200  ['Ph.D.s-', 'Postdocs', 'Ph.D.s', 'Highly', 'M...
# 201  ['Computer', 'Science', 'Engineering', 'Scienc...
# 202  ['Candidate', 'Work', 'Singapore', 'Computer',...
# 203  ['SKILLS', 'REQUIREDExperience', 'Double', 'Cl...
# 204  ['Bachelor', '’', 'Computer', 'Engineering', '...
# 205  ['BA/BS', 'English', 'Albert', 'LiewEA', 'Lice...
# 206  ['Bachelor', '’', 'Internet', 'Internet', 'Rec...
# 207  ['Bachelor', '’', 'Experience', 'Experience', ...
# 208  ['Robot', 'Operating', 'System', 'ROS', 'Famil...
# 209  ['Bachelor', 'Computer', 'Science', 'Engineeri...
# 210  ['Value', 'Singapore', 'Strong', 'Excellent', ...
# 211  ['Diploma', 'Computer', 'Science', 'Computer',...
# 212  ['Diploma', 'Understand', 'Machine', 'Data', '...
# 213                                                 []
# 214  ['Computer', 'Science', 'Engineering', 'Maths'...
# 215  ['Bachelor', '’', 'Degree', 'Computer', 'Scien...
#
#                                    job_description_nnp  \
# 0    ['Property', 'Guru', 'Southeast', 'Asia.Our', ...
# 1    ['Property', 'Guru', 'Southeast', 'Asia.Our', ...
# 2    ['Join', 'Fraud', 'Investigation', 'Dispute', ...
# 3    ['Agency', 'Science', 'Technology', 'Research'...
# 4           ['Specialize', 'PLC', 'Microgrid', 'EPGC']
# 5    ['Role', 'IAG', 'Data', 'Scientist', 'IAG', 'D...
# 6    ['Smart', 'Nation', 'Digital', 'Government', '...
# 7    ['Data', 'Analytics', 'Data', 'Lake', 'Dev', '...
# 8    ['Create', 'Guide', 'Manage', 'Hive', 'Data', ...
# 9    ['Create', 'Guide', 'Manage', 'Hive', 'Data', ...
# 10   ['Roles', 'Responsibilities', 'Us', 'Nation.Ma...
# 11   ['Application', 'Production', 'Support', 'Anal...
# 12   ['Job', 'Responsibilities', 'Align', 'R', 'Pyt...
# 13   ['Object', 'SEarch', 'ROSE', 'Lab', 'Nanyang',...
# 14   ['Mind.Capital', 'Mind.leverages.expert', 'Pro...
# 15   ['Microsoft', 'Microsoft', '’', 'Azure', 'Azur...
# 16   ['Impress', 'UsA', 'Maths', 'Physics', 'Machine']
# 17   ['Assistant', 'Director', 'Data', 'Science', '...
# 18   ['Role', 'Report', 'Data', 'Science', 'Dept', ...
# 19   ['Profile', 'Morgan', 'Stanley', 'Morgan', 'St...
# 20          ['RA', 'RA', 'Dr', 'Anupam', 'Gupta', '@']
# 21   ['Job', 'Purpose', 'Generation', 'Analytics.Ke...
# 22   ['Institute', 'High', 'Performance', 'Computin...
# 23   ['Data', 'Science', 'Singapore', 'Hadoop', 'SQ...
# 24   ['Data', 'Scientist', 'Data', 'Scientist', 'He...
# 25   ['Institute', 'Media', 'Innovation', 'Nanyang'...
# 26   ['Institute', 'Media', 'Innovation', 'Nanyang'...
# 27                                                  []
# 28                                                  []
# 29   ['IT/Digital', 'IT/Digital', 'IT/Digital', 'IT...
# ..                                                 ...
# 186  ['Agency', 'Science', 'Technology', 'Research'...
# 187  ['Are', 'Data', 'Science', 'Consultant', 'Palo...
# 188  ['Job', 'Purpose', 'AI', 'Machine', 'Learning'...
# 189  ['SIA', 'Enterprise', 'Information', 'Manageme...
# 190  ['AXA', 'Group', 'Insurance', 'Asset', 'Manage...
# 191  ['School', 'Civil', 'Environmental', 'Engineer...
# 192  ['Industry', 'Internet', 'Things', 'Semantic',...
# 193  ['Develop', 'Python', 'GPU', 'Backend/Frontend...
# 194                ['Develop', 'Understand', 'Create']
# 195  ['Fashion', 'Group', '“', 'GFG', '”', 'ZALORA'...
# 196  ['Daimler', 'Financial', 'Services', 'Singapor...
# 197       ['APIs', 'Work', 'Help', 'Understand', 'AI']
# 198  ['SCHOOL', 'OF', 'ELECTRICAL', 'AND', 'ELECTRO...
# 199  ['Analytics', 'Capable', 'Data', 'Analytics', ...
# 200  ['Analytics', 'Capable', 'Data', 'Analytics', ...
# 201                              ['Interact', 'Peach']
# 202  ['Understand', 'Undertake', 'Build', 'Data', '...
# 203  ['Background', 'Prospect', 'Dentsu', 'Aegis', ...
# 204                                          ['MySQL']
# 205  ['Company', 'Byte', 'Mod', 'Bytedance', 'Fast'...
# 206  ['Company', 'Byte', 'Mod', 'Bytedance', 'Fast'...
# 207  ['Company', 'Byte', 'Mod', 'Bytedance', 'Fast'...
# 208  ['RACE', 'Academy', 'Description', 'Develop', ...
# 209  ['Create', 'Lean', 'Design', 'Thinking', 'Agil...
# 210  ['Smart', 'Nation', 'Digital', 'Government', '...
# 211  ['Development', 'Lead', 'Agile', 'Development'...
# 212  ['BAF', 'Data', 'Analytics', 'Business', 'Data...
# 213  ['Industry', 'Engagement', 'National', 'Health...
# 214  ['R', 'D', 'Social', 'Media', 'Telco', 'Hadoop...
# 215  ['Job', 'Responsibilities', 'R', 'D', 'Data', ...
#
#                                     job_requirement_vb  \
# 0    ['s', 'be', 'working', 'Working', 'write', 'is...
# 1    ['s', 'be', 'working', 'Working', 'write', 'is...
# 2    ['qualify', 'have', 'is', 'encouraged', 'apply...
# 3    ['building', 'work', 'been', 'seek', 'develop'...
# 4    ['related', 'programming', 'work', 'Willing', ...
# 5    ['are', 'are', 'looking', 'extracting', 'disco...
# 6    ['are', 'following', 'take', 'going', 'provide...
# 7    ['have', 'done', 'have', 'debugging', 'have', ...
# 8    ['Passionate', 'asking', 'answering', 'be', 'c...
# 9    ['Passionate', 'asking', 'answering', 'be', 'c...
# 10   ['Need', 'are', 'looking', 'working', 'messagi...
# 11   ['s', '/', 'be', 'related', 'working', 'apply'...
# 12   ['is', 'using', 'analyzing', 'writing', 'skill...
# 13   ['related', 'have', 'have', 'is', 'be', 'is', ...
# 14   ['s', 'managing', 'building', 'databasing', 'd...
# 15   ['have', 'based', 'have', 'developing', 'deplo...
# 16   ['is', 'align', 'stretch', 'help', 'grow', 'im...
# 17   ['be', 'required', 'leading', 'collaborating',...
# 18   ['haves', 'learning', 'following', 'processing...
# 19   ['Demonstrated', 'learn', 'Demonstrated', 'des...
# 20   ['programming', 'implementing', 'learning', 'm...
# 21   ['meet', 'link', 'and/or', 'using', 'etc.Hands...
# 22                             ['Science/Engineering']
# 23   ['degree', 'oriented', 'scripting', 'programmi...
# 24   ['Let', 's', 'get', 'excited', 'have', 'workin...
# 25   ['hold', 'related', 'have', 'mentioned', 'evid...
# 26   ['hold', 'related', 'have', 'mentioned', 'evid...
# 27   ['Science/Engineering', 'are', 'include', 'bas...
# 28   ['Science/Engineering', 'are', 'include', 'bas...
# 29   ['have', 'architecting', 'solutioning', 'invol...
# ..                                                 ...
# 186  ['be', 'preferred', 'are', 'include', 'based',...
# 187  ['hold', 'degree', 'related', 'is', 'required'...
# 188  ['working', 'programing', 'coding', 'etc.Good'...
# 189  ['is', 'required', 'related', 'preferred.At', ...
# 190  ['s', 'computing', 'choose', 'is', 'is', 'work...
# 191                                ['work', 'working']
# 192  ['skills', 'do', 'have', 'programming', 'writt...
# 193     ['work', 'written', 'programming', 'packages']
# 194  ['solving', 'related', 'using', 'driven', 'rel...
# 195  ['Having', 'clustering', 'algorithms.Having', ...
# 196  ['versed', 'applied', 'learning', 'etc.•', 'et...
# 197  ['is', 'be', 'proficient', 'enforce', 'learnin...
# 198                                                 []
# 199  ['are', 'looking', 'are', 'want', 'return', 'f...
# 200  ['are', 'looking', 'are', 'want', 'return', 'f...
# 201  ['designing', 'developing', 'learning', 'testi...
# 202  ['possess', 'mentioned', 'possess', 'is', 'wor...
# 203  ['marketing', 'warehousing', 'including', 'dev...
# 204  ['Required', 's', 'skills.Required', 'is', 'pr...
# 205  ['Demonstrated', 'Demonstrated', 'working', 'w...
# 206  ['is', 'understanding', 'set', 'written/editin...
# 207  ['s', 'work', 'working', 'working', 'is', 'pre...
# 208  ['Have', 'developing', 'using', 'etc.Keen', 'p...
# 209  ['is', 'required', 'oriented', 'including', 'i...
# 210  ['are', 'following', 'take', 'going', 'provide...
# 211  ['related', 'leading', 'using', 'test', 'and/o...
# 212  ['graduates', 'be', 'working', 'take', 'unders...
# 213                                                 []
# 214  ['be', 'relating', 'is', 'is', 'work', 'involv...
# 215  ['s', 'including', 'and/or', 'sourced', 'commu...
#
#                                     job_description_vb  latitude  longtitude  \
# 0    ['result', 'has', 'is', 'empowered', 'build', ...  1.300213  103.837286
# 1    ['result', 'has', 'is', 'empowered', 'build', ...  1.300213  103.837286
# 2    ['help', 'work', 'be', 'aligned', 'works', 'ex...  1.280895  103.851677
# 3    ['is', 'fosters', 'drive', 'transform', '.For'...  1.285407  103.850568
# 4    ['applying', 'analysis.Specialize', 'modeling'...  1.285407  103.850568
# 5    ['focuses', 'creating', 'is', 'is', 'deliverin...  1.279468  103.853750
# 6    ['prioritizes', 'raises', 'builds', 'promotes'...       NaN         NaN
# 7    ['be', 'end', 'be', 'be', 'work', '’', '\uf0b7...  1.275857  103.845955
# 8    ['Lead', 'support', 'following', 'discover', '...  1.285407  103.850568
# 9    ['Lead', 'support', 'following', 'discover', '...  1.285407  103.850568
# 10   ['Power', 'develop', 'create', 'are', 'assembl...  1.325516  103.872258
# 11   ['is', 'holding', 'are', 'looking', 'support',...  1.275857  103.845955
# 12   ['prioritize', 'address', 'Using', 'scoop', 'd...  1.336050  103.889986
# 13   ['is', 'Peking', 'aims', 'create', 'are', 'be'...  1.346603  103.681356
# 14   ['is', 'strives', 'develop', 'combined', 'are'...  1.285785  103.852220
# 15   ['apply', 'have', 'heard', '’', 'going', "'s",...  1.285407  103.850568
# 16   ['loves', 'solves', 'fascinated', 'wants', 'le...  1.352062  103.860698
# 17   ['advance', 'programme', 'leveraging', 'drive'...  1.279331  103.838315
# 18   ['Get', 'know', 'optimising', 'employing', 'te...  1.276981  103.848409
# 19   ['is', 'leading', 'providing', 'located', 'ser...  1.282288  103.852774
# 20   ['be', 'come', 'learning', 'be', 'implement', ...  1.297245  103.781158
# 21   ['is', 'provide', 'meet', 'deliver', 'contribu...  1.334132  103.965833
# 22   ['s', 'was', 'established', 'provide', 'seeks'...  1.285407  103.850568
# 23   ['are', 'considering', 'are', 'based', 'has', ...  1.283205  103.851910
# 24   ['are', 'seeking', 'join', 'based', 'focus', '...  1.380194  103.974116
# 25   ['invites', 'include', 'contribute', 'exciting...  1.346603  103.681356
# 26   ['invites', 'include', 'contribute', 'exciting...  1.346603  103.681356
# 27   ['perform', 'applied', 'learning', 'including'...  1.285407  103.850568
# 28   ['perform', 'applied', 'learning', 'including'...  1.285407  103.850568
# 29   ['develop', 'provide', 'addressing', 'build', ...  1.278941  103.851256
# ..                                                 ...       ...         ...
# 186  ['is', 'world-class', 'drive', 'transform', 'A...  1.285407  103.850568
# 187  ['was', 'failed', 'are', 'right', 'deal', 'wer...  1.285894  103.849640
# 188  ['are', 'looking', 'join', '.focus', 'moving',...  1.280919  103.848244
# 189  ['has', 'implemented', 'is', 'is', 'looking', ...  1.377163  103.997294
# 190  ['advises', 'meeting', 'wealth', 'is', 'expres...  1.275731  103.847220
# 191  ['is', 'seeking', 'Assist', '–', 'Modelling', ...  1.346603  103.681356
# 192  ['are', 'looking', 'aims', 'associated', 'expl...  1.303997  103.774033
# 193  ['aims', 'become', 'existing', 'written', 'usi...  1.297245  103.781158
# 194  ['related', 'address', 'identify', 'solve', 'f...  1.296781  103.786757
# 195  ['is', 'emerging', 'operates', 'employs', 'is'...  1.274399  103.842261
# 196  ['is', 'headquartered', 'provides', 'includes'...  1.334599  103.742944
# 197  ['learning', 'are', 'optimize', 'Keep', 'be', ...  1.290761  103.784855
# 198  ['Established', 'is', 'is', 'renowned', 'are',...  1.346603  103.681356
# 199  ['designing', 'delivering', 'applying', 'are',...  1.296862  103.852213
# 200  ['designing', 'delivering', 'applying', 'are',...  1.296862  103.852213
# 201  ['define', 'deliver', 'existing', 'products.Ap...  1.335786  103.885510
# 202  ['build', 'address', 'involve', 'crunching', '...  1.273209  103.845282
# 203  ['helps', 'develop', 'support', 'developing', ...  1.276800  103.845618
# 204  ['is', 'expected', 'design', 'implement', 'bas...  1.346603  103.681356
# 205  ['known', 'founded', 'is', 'launch', 'powered'...  1.278128  103.847855
# 206  ['known', 'founded', 'is', 'launch', 'powered'...  1.278128  103.847855
# 207  ['known', 'founded', 'is', 'launch', 'powered'...  1.278128  103.847855
# 208  ['is', 'training', 'delivers', 'are', 'looking...  1.443384  103.836620
# 209  ['challenging', 'apply', 'solving', 'is', 'inn...  1.300213  103.837286
# 210  ['prioritizes', 'raises', 'builds', 'promotes'...  1.290592  103.849904
# 211  ['are', 'seeking', 'take', 'leading', 'using',...  1.274826  103.799074
# 212  ['are', 'looking', "who's.interested", 'using'...  1.274826  103.799074
# 213  ['is', 'involve', 'collect', 'matched', 'creat...  1.279331  103.838315
# 214  ['are', 'looking', 'work', 'focused', 'related...  1.446272  103.783229
# 215  ['are', 'looking', 'work', 'take', 'designing'...  1.446272  103.783229
#
#      job_experience             job_degree
# 0                 2               Bachelor
# 1                 2               Bachelor
# 2             eight
# 3                 5       Bachelor, Master
# 4                              Master, PhD
# 5                              Master, PhD
# 6                 2
# 7                 3                 Master
# 8                                 Bachelor
# 9                                 Bachelor
# 10
# 11                1       Bachelor, Master
# 12                                  Master
# 13                                Bachelor
# 14                3               Bachelor
# 15                5               Bachelor
# 16                   Bachelor, Master, PhD
# 17                5
# 18                3            Master, PhD
# 19                2
# 20                                  Master
# 21
# 22                                     PhD
# 23                   Bachelor, Master, PhD
# 24                             Master, PhD
# 25                                     PhD
# 26                                  Master
# 27                                     PhD
# 28                                     PhD
# 29
# ..              ...                    ...
# 186               2
# 187                  Bachelor, Master, PhD
# 188               2               Bachelor
# 189               3               Bachelor
# 190               4       Bachelor, Master
# 191               1                 Master
# 192                                    PhD
# 193               2
# 194                            Master, PhD
# 195               5            Master, PhD
# 196
# 197               3            Master, PhD
# 198                                 Master
# 199                            Master, PhD
# 200                            Master, PhD
# 201
# 202
# 203
# 204                               Bachelor
# 205            five               Bachelor
# 206               3               Bachelor
# 207               5               Bachelor
# 208
# 209               6               Bachelor
# 210               2
# 211                                Diploma
# 212               3        Master, Diploma
# 213
# 214
# 215                               Bachelor
#
# [216 rows x 22 columns]

# %%
import nltk
from nltk import word_tokenize
from nltk.tag.stanford import StanfordPOSTagger, StanfordNERTagger
import os
from nltk import pos_tag_sents
from nltk import pos_tag
import os

# %% [markdown]
# ### Use Standford NLP to see the POS tag and extract the NN and VERB

# %%
java_path = '/usr/bin/java'
os.environ['JAVAHOME'] = java_path

pos_model_path = './stanford-postagger-full-2018-02-27/models/english-bidirectional-distsim.tagger'
pos_jar_path = './stanford-postagger-full-2018-02-27/stanford-postagger.jar'

st_pos=StanfordPOSTagger(pos_model_path, pos_jar_path)

def pos_tag_nn(sent):
    words_tag = st_pos.tag(word_tokenize(sent))
    nn_pos_tag = [w for (w, t) in words_tag if 'NN' in t]
    return nn_pos_tag

def pos_tag_nnp(sent):
    words_tag = st_pos.tag(word_tokenize(sent))
    nnp_pos_tag = [w for (w, t) in words_tag if 'NNP' in t]
    return nnp_pos_tag    

def pos_tag_vb(sent):
    words_tag = st_pos.tag(word_tokenize(sent))
    vb_pos_tag = [w for (w, t) in words_tag if 'VB' in t]
    return vb_pos_tag
    
data['job_requirement_nn'] = data['job_requirement'].apply(lambda req: pos_tag_nn(req))
data['job_description_nn'] = data['job_description'].apply(lambda des: pos_tag_nn(des))

data['job_requirement_nnp'] = data['job_requirement'].apply(lambda req: pos_tag_nnp(req))
data['job_description_nnp'] = data['job_description'].apply(lambda des: pos_tag_nnp(des))

data['job_requirement_vb'] = data['job_requirement'].apply(lambda req: pos_tag_vb(req))
data['job_description_vb'] = data['job_description'].apply(lambda des: pos_tag_vb(des))

# %%
data['job_requirement_nn'] = data['job_requirement_nn'].apply(lambda x: ' '.join(x))
data['job_description_nn'] = data['job_description_nn'].apply(lambda x: ' '.join(x))

data['job_requirement_nnp'] = data['job_requirement_nnp'].apply(lambda x: ' '.join(x))
data['job_description_nnp'] = data['job_description_nnp'].apply(lambda x: ' '.join(x))

data['job_requirement_vb'] = data['job_requirement_vb'].apply(lambda x: ' '.join(x))
data['job_description_vb'] = data['job_description_vb'].apply(lambda x: ' '.join(x))

# %%
data = pd.read_csv('./processed_data.csv')
def get_more_detail(df):
    
    api_basic = 'https://api.mycareersfuture.sg/job/{}'
    df['latitude'] = df['job_uuid'].apply(lambda x: fetch_data(api_basic.format(x), {}, {})['lat'])
    df['longtitude'] = df['job_uuid'].apply(lambda x: fetch_data(api_basic.format(x), {}, {})['lng'])
    return df
    
    
data = get_more_detail(data)

# %%
data.to_csv('./processed_data.csv', index=False)

# %%
data
# Out:
#                            category  \
# 0                   Engineering ...
# 1                   Engineering ...
# 2    Accounting ,Auditing ,Taxation
# 3         Sciences ,Laboratory ,R&D
# 4         Sciences ,Laboratory ,R&D
# 5                   Engineering ...
# 6             Public ,Civil Service
# 7            Information Technology
# 8               Banking and Finance
# 9               Banking and Finance
# 10           Information Technology
# 11              Banking and Finance
# 12           Information Technology
# 13        Sciences ,Laboratory ,R&D
# 14           Information Technology
# 15                      Consulting
# 16           Information Technology
# 17   Healthcare ,Pharmaceutical ...
# 18           Information Technology
# 19              Banking and Finance
# 20        Sciences ,Laboratory ,R&D
# 21              Banking and Finance
# 22        Sciences ,Laboratory ,R&D
# 23              Advertising ,Media
# 24                  Engineering ...
# 25        Sciences ,Laboratory ,R&D
# 26        Sciences ,Laboratory ,R&D
# 27        Sciences ,Laboratory ,R&D
# 28        Sciences ,Laboratory ,R&D
# 29           Information Technology
# ..                              ...
# 186       Sciences ,Laboratory ,R&D
# 187          Information Technology
# 188          Information Technology
# 189          Information Technology
# 190             Banking and Finance
# 191                     Engineering
# 192                 Engineering ...
# 193                          Others
# 194          Information Technology
# 195                     Engineering
# 196          Information Technology
# 197                     Engineering
# 198       Sciences ,Laboratory ,R&D
# 199          Education and Training
# 200          Education and Training
# 201                      Design ...
# 202          Information Technology
# 203             Advertising ,Media
# 204       Sciences ,Laboratory ,R&D
# 205    Marketing ,Public Relations
# 206    Marketing ,Public Relations
# 207    Marketing ,Public Relations
# 208      Education and Training ...
# 209          Information Technology
# 210           Public ,Civil Service
# 211      Information Technology ...
# 212      Information Technology ...
# 213       Environment ,Health   ...
# 214      Education and Training ...
# 215      Education and Training ...
#
#                                                company employment_type  \
# 0                               PROPERTYGURU PTE. LTD.      Permanent
# 1                               PROPERTYGURU PTE. LTD.      Permanent
# 2                     ERNST & YOUNG ADVISORY PTE. LTD.      Permanent
# 3                             A*STAR RESEARCH ENTITIES       Contract
# 4                             A*STAR RESEARCH ENTITIES       Contract
# 5                                  Company Undisclosed      Permanent
# 6           Smart Nation and Digital Government Office       Full Time
# 7                           SCHELLDEN GLOBAL PTE. LTD.       Full Time
# 8                                  Company Undisclosed       Full Time
# 9                                  Company Undisclosed       Full Time
# 10                             SINGAPORE POWER LIMITED       Permanent
# 11         IT CONSULTING SOLUTIONS SINGAPORE PTE. LTD.        Contract
# 12               CHARLES & KEITH (SINGAPORE) PTE. LTD.       Full Time
# 13                    NANYANG TECHNOLOGICAL UNIVERSITY       Contract
# 14                         DEEP MIND CAPITAL PTE. LTD.       Full Time
# 15                                 Company Undisclosed       Full Time
# 16                                HANALYTICS PTE. LTD.      Permanent
# 17                              Health Promotion Board       Permanent
# 18                         GRABTAXI HOLDINGS PTE. LTD.       Full Time
# 19                MORGAN STANLEY ASIA (SINGAPORE) PTE.       Full Time
# 20                    NATIONAL UNIVERSITY OF SINGAPORE       Contract
# 21                                       CITIBANK N.A.       Full Time
# 22                            A*STAR RESEARCH ENTITIES       Contract
# 23                                 Company Undisclosed       Full Time
# 24                               RESMED ASIA PTE. LTD.      Permanent
# 25                    NANYANG TECHNOLOGICAL UNIVERSITY       Contract
# 26                    NANYANG TECHNOLOGICAL UNIVERSITY       Contract
# 27                            A*STAR RESEARCH ENTITIES       Contract
# 28                            A*STAR RESEARCH ENTITIES       Contract
# 29                                    CAPITA PTE. LTD.       Full Time
# ..                                                 ...             ...
# 186                           A*STAR RESEARCH ENTITIES       Contract
# 187                        PALO IT SINGAPORE PTE. LTD.      Permanent
# 188                          DATHENA SCIENCE PTE. LTD.      Permanent
# 189                         SINGAPORE AIRLINES LIMITED       Permanent
# 190                             AXA DIL@ASIA PTE. LTD.       Full Time
# 191                   NANYANG TECHNOLOGICAL UNIVERSITY       Contract
# 192  CAMBRIDGE CENTRE FOR ADVANCED RESEARCH AND EDU...       Full Time
# 193                   NATIONAL UNIVERSITY OF SINGAPORE       Contract
# 194                           KKT TECHNOLOGY PTE. LTD.       Full Time
# 195        GLOBAL FASHION GROUP SGP SERVICES PTE. LTD.       Full Time
# 196                                Company Undisclosed       Full Time
# 197                         DYSON OPERATIONS PTE. LTD.      Permanent
# 198                   NANYANG TECHNOLOGICAL UNIVERSITY       Contract
# 199                    SINGAPORE MANAGEMENT UNIVERSITY       Full Time
# 200                    SINGAPORE MANAGEMENT UNIVERSITY       Full Time
# 201                      PEACH INTELLIHEALTH PTE. LTD.       Full Time
# 202                           CPM CONSULTING PTE. LTD.       Permanent
# 203        DENTSU AEGIS NETWORK ASIA PACIFIC PTE. LTD.      Permanent
# 204                   NANYANG TECHNOLOGICAL UNIVERSITY       Contract
# 205                 BIPO SERVICE (SINGAPORE) PTE. LTD.       Full Time
# 206                 BIPO SERVICE (SINGAPORE) PTE. LTD.       Full Time
# 207                 BIPO SERVICE (SINGAPORE) PTE. LTD.       Full Time
# 208                                PBA SYSTEMS PTE LTD       Permanent
# 209                                Company Undisclosed       Permanent
# 210                            Public Service Division       Full Time
# 211                       GOVERNMENT TECHNOLOGY AGENCY       Permanent
# 212                       GOVERNMENT TECHNOLOGY AGENCY       Full Time
# 213                             Health Promotion Board       Full Time
# 214                               Republic Polytechnic        Contract
# 215                               Republic Polytechnic        Contract
#
#                                        job_description  \
# 0    Our websites attract more than 100 million mon...
# 1    Our websites attract more than 100 million mon...
# 2    Join Fraud Investigation & Dispute Services (F...
# 3    The Agency for Science, Technology and Researc...
# 4    Specialize in applying data analytics, machine...
# 5    About The Role. As IAG focuses on creating an ...
# 6    The Smart Nation and Digital Government Office...
# 7    You will be responsible for end to end develop...
# 8    . Lead the definition of activities, scope, an...
# 9    . Lead the definition of activities, scope, an...
# 10   Roles & Responsibilities. Why Work for Us. We ...
# 11   Our client is an investment holding company. T...
# 12   Job Responsibilities. Align, understand and pr...
# 13   The Rapid-Rich Object SEarch (ROSE) Lab is a j...
# 14   Deep Mind.Capital is a digital asset managemen...
# 15   Interested applicant please apply via this lin...
# 16   Who Will Impress UsA strong technical individu...
# 17   Assistant Director, Data Science. Overview of ...
# 18   Get to know the Role:Report into the Data Scie...
# 19   Company Profile. Morgan Stanley is a leading g...
# 20   The RA will be responsible to come up with new...
# 21   Job Purpose:The charter of this role is to pro...
# 22   About the Institute of High Performance Comput...
# 23   We are considering candidates for both junior ...
# 24   Data Scientist. We are currently seeking appli...
# 25   The Institute for Media Innovation ( http://im...
# 26   The Institute for Media Innovation ( http://im...
# 27   The candidate will perform both fundamental re...
# 28   The candidate will perform both fundamental re...
# 29   Solves complex technical problem/solution.Cons...
# ..                                                 ...
# 186  The Agency for Science, Technology and Researc...
# 187  Your profile & role on the projectYOU:Thrive o...
# 188  Job Purpose. We are looking for an AI and Mach...
# 189  SIA has implemented the Enterprise Information...
# 190  The AXA Group, a worldwide leader in Insurance...
# 191  The School of Civil and Environmental Engineer...
# 192  Who are we looking for?The project aims at a c...
# 193  Develop software as a part of a young, dynamic...
# 194  Responsibilities. Develop predictive models on...
# 195  Global Fashion Group (“GFG”) is the #1 online ...
# 196  Daimler Financial Services is headquartered in...
# 197  Design and implement machine learning applicat...
# 198  Established in 1981, the SCHOOL OF ELECTRICAL ...
# 199  (1) Analytics(a) Capable of designing and deli...
# 200  (1) Analytics(a) Capable of designing and deli...
# 201  Responsibilities. Interact with business, tech...
# 202  Primary Responsibilities:Understand large data...
# 203  Background. The i. Prospect global product tea...
# 204  The candidate is expected to design and implem...
# 205  Our Client's Company background: Byte. Mod (al...
# 206  Our Client's Company background: Byte. Mod (al...
# 207  Our Client's Company background: Byte. Mod (al...
# 208  RACE Academy (http://raceacademy.com.sg) is a ...
# 209  Profile:Create value by challenging the status...
# 210  The Smart Nation and Digital Government Office...
# 211  We are seeking a Development Lead to take on t...
# 212  BAF (Data Analytics)We are looking for Busines...
# 213  Strategy and Industry Engagement lead, Technol...
# 214  Responsibilities. We are looking for a respons...
# 215  Job Responsibilities. We are looking for a cap...
#
#                                        job_requirement  \
# 0    Bachelor’s degree in IT or relevant field. Alt...
# 1    Bachelor’s degree in IT or relevant field. Alt...
# 2    To qualify for the role you must have. Strong ...
# 3    Bachelor or Master's Degree in physical scienc...
# 4    PhD in Power System operation and analysis or ...
# 5    These are the skills and experience we are loo...
# 6    We are in search of motivated individuals who ...
# 7    What you have done: Commercial software engin...
# 8    Knowledge in at least 1 of the following data ...
# 9    Knowledge in at least 1 of the following data ...
# 10   Requirements. What You'll Need. We are looking...
# 11   -. At least 1 year hands-on experience in crit...
# 12   Requirement. At least a Degree or Masters in M...
# 13   Bachelor degree in Computer Science, Electrica...
# 14   Bachelor’s degree with 3 years minimum experie...
# 15   Must have deep hands-on.experience with On-pre...
# 16   The Candidate. Our aim is to align you with th...
# 17   . Qualification or work experience in data sci...
# 18   he must haves:Ph.D. graduate, or Masters(with ...
# 19   Skills Required2+ years of experience. Educati...
# 20   Advanced Skills in current Machine Learning Te...
# 21   The ideal candidate will meet the following re...
# 22   PhD degree in Computer Science/Engineering wit...
# 23   Requirements:Bachelor’s, Master’s or PhD degre...
# 24   Let’s talk about you:To really get us excited,...
# 25   The candidates should hold a Doctorate degree ...
# 26   The candidates should hold a Master degree fro...
# 27   PhD in Computer Science/Engineering with exper...
# 28   PhD in Computer Science/Engineering with exper...
# 29   Must have experience in large-scale projects/p...
# ..                                                 ...
# 186  Degree holder in computer science, EEE or mech...
# 187  You hold a Bachelor, Master or PhD degree in C...
# 188  Skills and Qualifications2+ years experience i...
# 189  BS in Computer Science or other related discip...
# 190  Successful qualifier of this mission:Professio...
# 191  Master degree in Computer Science, Computer En...
# 192  What skills do you have?A PhD degree in a rele...
# 193  Postgraduate university degree in IT, science ...
# 194  Requirements. Minimum. Deep understanding of s...
# 195  Your Skills and Experience:Having a Ph.D. or M...
# 196  • Degree in Computer Science, Mathematics, Phy...
# 197  Strong quantitative background; a master degre...
# 198  Master degree in Electrical and Computer Engin...
# 199  (1) We are continually on the lookout for outs...
# 200  (1) We are continually on the lookout for outs...
# 201  Quantitative background with advanced degree(s...
# 202  Candidate should possess good soft skills as m...
# 203  SKILLS REQUIREDExperience in marketing big dat...
# 204  Required qualifications:A Bachelor’s degree in...
# 205  BA/BS degree in marketing, advertising, techno...
# 206  Bachelor’s degree is required.Minimum 3 years ...
# 207  Bachelor’s degree;5+ years work experience in ...
# 208  A degree in electrical/electronic/computer eng...
# 209  Job Requirements:Bachelor's degree in Computer...
# 210  We are in search of motivated individuals who ...
# 211  :Degree or Diploma in Computer Science, Comput...
# 212  :Degree/Master in any discipline; Diploma grad...
# 213                                              None.
# 214  Skills and Experience:•.Qualifications in Comp...
# 215  • At least a Bachelor’s Degree in Computer Sci...
#
#                                             job_skills  \
# 0    Data Analysis, SQL, Microsoft Excel, Microsoft...
# 1    Data Analysis, SQL, Microsoft Excel, Microsoft...
# 2    Accounting, Microsoft Excel, Microsoft Word, G...
# 3    Matlab, Algorithms, C++, Machine Learning, C, ...
# 4    R&D, Molecular Biology, Biotechnology, Lifesci...
# 5    Analytics, Data Analysis, Analysis, Statistica...
# 6    Human Resources, Employee Relations, Recruitin...
# 7    Engineering, Project Management, Testing, Soft...
# 8    Management, Leadership, Strategy, Strategic Pl...
# 9    Management, Leadership, Strategy, Strategic Pl...
# 10   Linux, Windows Server, Microsoft SQL Server, M...
# 11   JavaScript, SQL, Java, XML, Microsoft SQL Serv...
# 12   Databases, Microsoft SQL Server, SQL, Business...
# 13   Research, Matlab, Data Analysis, C++, Microsof...
# 14   Management, Leadership, Project Management, St...
# 15   Architecture, Architectural Design, Sustainabl...
# 16   Algorithms, Software Engineering, Computer Sci...
# 17   Analytics, Data Analysis, Analysis, Statistica...
# 18   Algorithms, Software Engineering, Computer Sci...
# 19   Management, Strategy, Leadership, Microsoft Of...
# 20   Research, Matlab, Data Analysis, C++, Microsof...
# 21   Business Analysis, Project Management, Managem...
# 22   R&D, Molecular Biology, Biotechnology, Lifesci...
# 23   Databases, Microsoft SQL Server, SQL, Business...
# 24   R&D, Molecular Biology, Biotechnology, Lifesci...
# 25   Research, Science, Matlab, LaTeX, Algorithms, ...
# 26   Research, Data Analysis, Matlab, Molecular Bio...
# 27   Matlab, Algorithms, C++, Machine Learning, C, ...
# 28   R&D, Molecular Biology, Biotechnology, Lifesci...
# 29   Management, Project Management, Strategy, Lead...
# ..                                                 ...
# 186  Matlab, Algorithms, C++, Machine Learning, C, ...
# 187  Analytics, Data Analysis, Analysis, Statistica...
# 188  Java, JavaScript, Software Development, C++, L...
# 189  Databases, SQL, Microsoft SQL Server, MySQL, D...
# 190  Data Management, Management, Databases, Micros...
# 191  Research, Data Analysis, Matlab, Molecular Bio...
# 192  Algorithms, Software Engineering, Computer Sci...
# 193  Research, Science, Matlab, LaTeX, Algorithms, ...
# 194  Market Research, Quantitative Research, Manage...
# 195  Engineering, Project Management, Testing, Matl...
# 196  Data Warehousing, Data Modeling, Business Inte...
# 197  Java, JavaScript, Software Development, C++, L...
# 198  Research, Data Analysis, Matlab, Molecular Bio...
# 199  Research, Teaching, Higher Education, Universi...
# 200  Research, Teaching, Higher Education, Universi...
# 201  Art, Photoshop, Drawing, Painting, Maya, Illus...
# 202  Management, Project Management, Strategy, Lead...
# 203  Cloud Computing, Integration, Pre-sales, Telec...
# 204  Matlab, Algorithms, C++, Machine Learning, C, ...
# 205  Marketing, Marketing Strategy, Marketing Commu...
# 206  Marketing, Marketing Strategy, Management, Sal...
# 207  Corporate Communications, Public Relations, Ma...
# 208  Engineering, Mechanical Engineering, Solidwork...
# 209  Solution Architecture, Cloud Computing, Integr...
# 210  Human Resources, Recruiting, Employee Relation...
# 211  Java, SharePoint, Software Development, Active...
# 212  Business Analysis, Project Management, Managem...
# 213  Management, Project Planning, Strategic Planni...
# 214  Matlab, Algorithms, C++, Machine Learning, C, ...
# 215  Statistics, Operations Research, Data Analysis...
#
#                                              job_title  \
# 0                                        Data Engineer
# 1                                        Data Engineer
# 2    Fraud Investigation & Dispute Services (FIDS) ...
# 3    Research Engineer / Senior Research Engineer (...
# 4             Scientist (Power System Analytics), EPGC
# 5                                       Data Scientist
# 6     Manager  /  Senior Manager (Talent and Manpower)
# 7                             senior big data engineer
# 8    Vice President, Portfolio & Regulatory Managem...
# 9    Vice President, Portfolio & Regulatory Managem...
# 10              Data Engineer  /  Senior Data Engineer
# 11              Application Production Support Analyst
# 12                                 Senior Data Analyst
# 13                                     Project Officer
# 14                                     Product Manager
# 15                                           Architect
# 16                           Machine Learning Engineer
# 17                    Assistant Director, Data Science
# 18                                      Data Scientist
# 19   Technology - Fusion Cyber Analytics Research a...
# 20                                  Research Assistant
# 21           GCG - Business Analyst Manager - 17053710
# 22                                    Scientist (IHPC)
# 23                    Data Scientist, APAC (Singapore)
# 24                                      Data Scientist
# 25                                     Research Fellow
# 26                                  Research Associate
# 27                                   Research Engineer
# 28                                           Scientist
# 29                                          Consultant
# ..                                                 ...
# 186  Research Engineer / Senior Research Engineer (...
# 187          Senior Analytics Manager - Data Scientist
# 188                                     Data Scientist
# 189                 Data Sciences & Analytics Engineer
# 190                              Data Science Engineer
# 191                                 Research Associate
# 192                                 Computer Scientist
# 193  Programmer for scientific image processing (Re...
# 194                                     Data Scientist
# 195                               GFG - Data Scientist
# 196  Assistant Manager - Data Science and Architecture
# 197                         Advanced Software Engineer
# 198                                 Research Associate
# 199  SIS - Associate Professor of Information Syste...
# 200  SIS - Assistant Professor of Information Syste...
# 201  Scientist  /  Senior Scientist, Artificial Int...
# 202                            Data Science Consultant
# 203                          Global Solutions Engineer
# 204                                  Research Engineer
# 205                                   Ad Sales Manager
# 206                        Marketing Operation Manager
# 207                          International PR Director
# 208                                   Robotic Engineer
# 209                                 Solution architect
# 210   Manager  /  Senior Manager (Talent and Manpower)
# 211  Development Lead (Assistant Director / Deputy ...
# 212                  Business Analyst (Data Analytics)
# 213  Senior Deputy Director  /  Deputy Director, Te...
# 214  School of Infocomm - Research Staff (Text Anal...
# 215  School of Infocomm - Research Staff (Data Anal...
#
#                              job_uuid    location  salary_max  \
# 0    82e462a13cadc477f93d57ad6812d1d1     Central      7000.0
# 1    763708ca5a581db4389a766ef71654a0     Central      9000.0
# 2    c59d6037f441a5b3b43ca4daff84806a     Central     16000.0
# 3    cec1905d6444838c2d7108c1a04049a3        West      5000.0
# 4    d2da04bb4033006cb580fc80e752fa9e        West     11800.0
# 5    972f2d0cd68c45fbf7d50920fc229036     Central     12000.0
# 6    cb3cb0fd4276956c30baab4084802b3a         NaN         0.0
# 7    6b9679d4563c270b58f3a9a89638564a  Islandwide      7000.0
# 8    e11a65ce7a59ca9f6a19bcf76c62ac68     Central     10000.0
# 9    dda2dea97c28a907fe2b7ee0346d4e77     Central     10000.0
# 10   4cd668c50a85ba02abd424a650a92136        East      8000.0
# 11   b10133c8d371d4dfe1de39400b5155f1       South      8000.0
# 12   6659d599806e295ca7bb79a243adb38b     Central      5000.0
# 13   0fad24b00ab6d9df9bdf41781f7b084a        West      4500.0
# 14   8c9fe53d59f2e9098b7dbd3c278b7fea     Central      8000.0
# 15   2b6342a137ded6093c9618d72f3155bf     Central     12500.0
# 16   7642a78635193da3ad8204a34daaf181     Central      5000.0
# 17   d2d8e6c23fb3649e7b224cbb6501b4cc         NaN         0.0
# 18   2a2ee56c3b3cec5ccff768b099f09fe1     Central     14500.0
# 19   bc3a4aa861e468e4cd232d59ccd5d256     Central     10000.0
# 20   9937de616b75ce1698384867975501d7       South      4000.0
# 21   3f3fe91fe7c5940b1ecc80f387d5ab14     Central     17500.0
# 22   dec9b53ccd64af7027d4cd08f3146992       South      9000.0
# 23   7a4299c3536619c564293048bea1cce1     Central     12000.0
# 24   2f0c26cd85b0964482421f8d9f7ec3bd       South      7000.0
# 25   913340be62541afd2571365b5eff0cf6        West      6500.0
# 26   5765a6d1b881d9536bcd64108f1d9b35        West      4000.0
# 27   31decfaf2092d81406301e735b1b8bdd       South      9000.0
# 28   cfe404cfd5e11fa12c61fa2d8d295bc7       South      9000.0
# 29   b798203ef1c4878b8ae6a0d38bef92fd        East      7000.0
# ..                                ...         ...         ...
# 186  d86d955368b41b2a543e1530bbe0269b        West      5000.0
# 187  3e0e537665209844cc7d4a32226f72ab     Central     12000.0
# 188  1312535ac143e9d7adadf7b1b67de06f        East      8000.0
# 189  91dfb5cd8304de2a385abcc64d798447        East      8000.0
# 190  63f272076a30b65095cc525f157f75f6     Central      5500.0
# 191  26a431ed77f4b3731d6827d8e0a261e8        West      3900.0
# 192  88752d547c94b04fd687d0a219e08948       South      9000.0
# 193  5d0685928fe7f8b10a586bb9e5cc4dea       South      6000.0
# 194  b325262b317035bca49c7c1983aaa144     Central      6200.0
# 195  8cc8f32b769bf4c78f63416d33f3855d     Central         NaN
# 196  15f94d0fb1d37ec49dcd011c504b746c        West      9000.0
# 197  0b1730faa83a9206c2c35b63e4018669  Islandwide      7500.0
# 198  de2c4fe319aaf7f9c98c514375415d7d        West      3800.0
# 199  a29402724a5dee58dd9e1868bb0223b1        East     20000.0
# 200  d05f18a2a92c3f5753a702058b8dead8        East     16000.0
# 201  282d8d7b999aa39cd49b8cadece1d298       South      7500.0
# 202  0a2a428522865a7fe47e40bdf563a6e6     Central      6500.0
# 203  d76ee47060586c49d4da5c9250da7f86     Central     13000.0
# 204  db520a7ed727d61d4e5f67b3b17fa27e        West      3850.0
# 205  8bb0f29ef4ec85d966db197e05aa67da  Islandwide     15000.0
# 206  6bda14d1b85d52eebb61338bce7b7a7b  Islandwide     12500.0
# 207  e37741199a4a9355511d41607df9dc5b  Islandwide     15000.0
# 208  2de35beaa36d164f9ea115cb88e35508       North      5200.0
# 209  41f6a7860a3f589ead027585ac65d574       South      6800.0
# 210  f01ff9fc64cb143fde616b8d97709616         NaN         0.0
# 211  bf0bfb2cfbc8208786d76ae0aa4bb1b9         NaN         0.0
# 212  9e6bb89686d7ae65bd6554890fd0ea0d         NaN         0.0
# 213  da6ff054ba8acee46b7ce3e5adb96e44         NaN         0.0
# 214  bdb3a8b22365e72310e2edc0fbfc737a         NaN         0.0
# 215  2dfa82ed3e823b2277f19dbd1538fc5d         NaN      5300.0
#
#              ...                                           job_requirement_nn  \
# 0            ...            Bachelor s degree IT field qualifications expe...
# 1            ...            Bachelor s degree IT field qualifications expe...
# 2            ...            role record degree field years experience audi...
# 3            ...            Bachelor Master Degree sciences track record s...
# 4            ...            PhD Power System operation analysis Computer S...
# 5            ...            skills experience Experience value datasets ma...
# 6            ...            search individuals traits experience Value int...
# 7            ...             Commercial software engineering .You years s...
# 8            ...            Knowledge data science domains Mining NLPGraph...
# 9            ...            Knowledge data science domains Mining NLPGraph...
# 10           ...            Requirements Passion Proficiency skill softwar...
# 11           ...            year experience production support.- s degree ...
# 12           ...            Requirement Degree Masters Mathematics Economi...
# 13           ...            Bachelor degree Computer Science Engineering f...
# 14           ...            Bachelor s degree years experience Business Fi...
# 15           ...            hands-on.experience On-prem Cloud data solutio...
# 16           ...            Candidate aim activities billions patients.Som...
# 17           ...            Qualification work experience data science/ana...
# 18           ...            haves Ph.D. graduate Masters ( years experienc...
# 19           ...            Skills years experience Education Computer Sci...
# 20           ...            Advanced Skills Machine Learning Techniques De...
# 21           ...            candidate requirements Business Product Knowle...
# 22           ...            PhD degree Computer expertise Machine Learning...
# 23           ...            Requirements s Master ’ s PhD degree Computer ...
# 24           ...            s talk knowledge machine theories data mining ...
# 25           ...            candidates Doctorate degree University area In...
# 26           ...            candidates Master degree University area Inter...
# 27           ...            PhD Computer expertise Machine Learning Optimi...
# 28           ...            PhD Computer expertise Machine Learning Optimi...
# 29           ...            experience projects/programs Transformation sk...
# ..           ...                                                          ...
# 186          ...            Degree holder computer science EEE engineering...
# 187          ...            Bachelor Master PhD degree Computer Science St...
# 188          ...            Skills years experience projects Spark environ...
# 189          ...            BS Computer Science discipline Advanced degree...
# 190          ...            qualifier mission skills Bachelor Master s deg...
# 191          ...            Master degree Computer Science Computer Engine...
# 192          ...            skills PhD degree discipline mathematics compu...
# 193          ...            Postgraduate university degree IT science engi...
# 194          ...            Requirements Minimum understanding modeling ma...
# 195          ...            Skills Experience Ph.D. Masters Degree Compute...
# 196          ...            • Degree Computer Science Mathematics Physics ...
# 197          ...            background master degree Computer Science Math...
# 198          ...            Master degree Computer Engineering experience ...
# 199          ...            ( ) lookout faculty candidates levels Ph.D.s- ...
# 200          ...            ( ) lookout faculty candidates levels Ph.D.s- ...
# 201          ...            background degree s ) majors Computer Science ...
# 202          ...            Candidate skills problem environment time.Exce...
# 203          ...            SKILLS REQUIREDExperience data solutions Data ...
# 204          ...            qualifications Bachelor s degree Computer Engi...
# 205          ...            BA/BS degree marketing advertising technology ...
# 206          ...            Bachelor s degree required.Minimum years exper...
# 207          ...            Bachelor s degree years experience communicati...
# 208          ...            degree electrical/electronic/computer engineer...
# 209          ...            Job Requirements Bachelor degree Computer Scie...
# 210          ...            search individuals traits experience Value int...
# 211          ...            Degree Diploma Computer Science Computer Elect...
# 212          ...            Degree/Master discipline Diploma graduates exp...
# 213          ...                                                         None
# 214          ...            Skills Experience •.Qualifications Computer Sc...
# 215          ...            • Bachelor ’ Degree Computer Science Engineeri...
#
#                                     job_description_nn  \
# 0    websites page-views click-stream behaviour dat...
# 1    websites page-views click-stream behaviour dat...
# 2    Fraud Investigation Dispute Services Assurance...
# 3    Agency Science Technology Research ( A*STAR ) ...
# 4    data analytics machine learning data mining te...
# 5    Role IAG organisation Data Scientist role data...
# 6    Smart Nation Digital Government Office ( SNDGO...
# 7    end development Data Analytics cases company D...
# 8    definition activities scope timelines data sci...
# 9    definition activities scope timelines data sci...
# 10   Roles Responsibilities Work Us Power Nation.Ma...
# 11   client investment company Application Producti...
# 12   Job Responsibilities Align goals business oppo...
# 13   Rapid-Rich Object SEarch ( ROSE ) Lab research...
# 14   Mind.Capital asset management company investme...
# 15   applicant link .https //careers.microsoft.com/...
# 16   UsA individual background computer science phy...
# 17   Assistant Director Data Science Overview Polic...
# 18   Role Report Data Science Dept insights dataset...
# 19   Company Profile Morgan Stanley services firm r...
# 20   RA approaches machine learning image/speech re...
# 21   Job Purpose charter role thought leadership su...
# 22   Institute High Performance Computing Institute...
# 23   candidates positions.Who Data Science team Sin...
# 24   Data Scientist applications Data Scientist Hea...
# 25   Institute Media Innovation Nanyang Technologic...
# 26   Institute Media Innovation Nanyang Technologic...
# 27   candidate research research area computer visi...
# 28   candidate research research area computer visi...
# 29   problem/solution.Consult design solutions tech...
# ..                                                 ...
# 186  Agency Science Technology Research ( A*STAR ) ...
# 187  profile role projectYOU challenge time change ...
# 188  Job Purpose AI Machine Learning developer team...
# 189  SIA Enterprise Information Management ( EIM ) ...
# 190  AXA Group leader Insurance Asset Management cu...
# 191  School Civil Environmental Engineering Nanyang...
# 192  project virtualisation park i.e representation...
# 193  software part start-up number image processing...
# 194  Responsibilities models healthcare datasets bu...
# 195  Global Fashion Group fashion platform markets ...
# 196  Daimler Financial Services Singapore Africa As...
# 197  Design machine learning application products e...
# 198  SCHOOL ELECTRICAL AND ELECTRONIC ENGINEERING (...
# 199  ( ) Analytics ) Capable level courses Data Ana...
# 200  ( ) Analytics ) Capable level courses Data Ana...
# 201  Responsibilities business teams solutions prod...
# 202  Responsibilities data sets data models busines...
# 203  Background Prospect product team clients marke...
# 204  candidate techniques malwares applications num...
# 205  Client Company background Byte Mod ( companies...
# 206  Client Company background Byte Mod ( companies...
# 207  Client Company background Byte Mod ( companies...
# 208  RACE Academy ( http robotics training company ...
# 209  Profile value status quo thinking creativity t...
# 210  Smart Nation Digital Government Office ( SNDGO...
# 211  Development role design development project so...
# 212  BAF ( Data Analytics ) Business Analysts Data ...
# 213  Strategy Industry Engagement lead Technology-E...
# 214  Responsibilities individual industry R D proje...
# 215  Job Responsibilities individual R D projects D...
#
#                                    job_requirement_nnp  \
# 0    IT Azkaban Airflow Python C++ Java Go Scala Ka...
# 1    IT Azkaban Airflow Python C++ Java Go Scala Ka...
# 2              Life Science English Plus Opportunities
# 3                                            Technical
# 4              Power System C/C++ Python Jurong Island
# 5    SQL Python Py Spark Scala AWS GCP Advanced Ten...
# 6    Value Singapore Smart Nation Analytical date.S...
# 7     Commercial Java Python ( Py skills. Big Had...
# 8    Mining NLPGraph Network Analysis Deep Learning...
# 9    Mining NLPGraph Network Analysis Deep Learning...
# 10                                   Java Python Kafka
# 11   Oracle MSSQL q/KDB+* Software Development expe...
# 12   Mathematics Economics Computer Science Informa...
# 13   Computer Science Engineering C/C++ Python MATL...
# 14   Business Finance IT ( Order Management System ...
# 15   Azure AWS Hadoop/Spark/Hive NoSQL Azure HDI Co...
# 16       Candidate C++ java5 RNN CNN Desired Education
# 17                                   Python SQL ) Able
# 18   Computer Science .Economics .Electrical/Comput...
# 19   Education Computer Science Mathematics Data Mi...
# 20   Advanced Machine Learning Techniques Deep Lear...
# 21   Decision Management ) Ability Machine Learning...
# 22       Computer Machine Learning ( C++ Python Java )
# 23   Master ’ Computer Science Statistics Math Engi...
# 24   Data Science Applied Statistics Biomedical Inf...
# 25   Doctorate University Interactive Digital Media...
# 26   Master University Interactive Digital Media Co...
# 27       Computer Machine Learning Optimization Python
# 28       Computer Machine Learning Optimization Python
# 29   Data Analytics Microservices RPA Blockchain AI...
# ..                                                 ...
# 186                                            Minimum
# 187  Computer Science Statistics Good SAS SPSS ( e....
# 188  Machine Learning Deep Learning Decision Tree/R...
# 189  Computer Science Advanced Analytics Machine Le...
# 190  ( HDFS Spark Hive Oozie ) Good ( Python Java S...
# 191  Computer Science Computer Engineering Electron...
# 192         CREATE Tower NUS University Town Singapore
# 193  IT Python C++ Java JS CUDA OpenCLPython Numpy/...
# 194  Minimum ( Python R ) Proficient Python Java C/...
# 195  Computer Science Applied Statistics Mathematic...
# 196  • Degree Computer Science Mathematics equivale...
# 197  Computer Science Mathematics Statistics C++ Ja...
# 198                          Computer Engineering CMOS
# 199  Education Practice-Track Assistant/Associate/F...
# 200  Education Practice-Track Assistant/Associate/F...
# 201  Computer Science Engineering Science Mathemati...
# 202  Work Singapore Computer Science Engineering Da...
# 203  Data Transfer/Match Table Ad Exchange Real Tim...
# 204  Computer Engineering Computer Science Good Eng...
# 205  Recruiter Albert LiewEA License No 18S9180EA P...
# 206  Recruiter Albert LiewEA License No 18S9180EA P...
# 207  Internet Technology Recruiter Albert LiewEA Li...
# 208                   Have Robot Operating System Able
# 209  Job Computer Science Engineering Javascript HT...
# 210  Value Singapore Smart Nation Analytical date.S...
# 211  Computer Science Computer Electronics Engineer...
# 212  Machine Python Rapid Miner Knime SAS Matlab Py...
# 213
# 214  Computer Science Engineering Maths Machine Lea...
# 215  Bachelor ’ Degree Computer Science Engineering...
#
#                                    job_description_nnp  \
# 0    Property Guru Southeast Asia.Our Data Science ...
# 1    Property Guru Southeast Asia.Our Data Science ...
# 2    Fraud Investigation Dispute Services Assurance...
# 3    Agency Science Technology Research ( A*STAR ) ...
# 4
# 5    IAG Data Scientist IAG Data Sciences IAG ( Bus...
# 6    Smart Nation Digital Government Office ( SNDGO...
# 7    Data Lake Dev Do Data Machine Learningplatform...
# 8        Guide Work Hive Data Work Data Scala Java API
# 9        Guide Work Hive Data Work Data Scala Java API
# 10   Work Us Power quality.We Build Reliable Soluti...
# 11   Enterprise Data Warehouse KDB+ Dev Ops Data An...
# 12          Job Responsibilities Align R Python etc.To
# 13   Rapid-Rich Object SEarch ( ROSE ) Lab Nanyang ...
# 14
# 15   Microsoft Microsoft ’ Azure Azure Azure.The Da...
# 16                                             Machine
# 17   Assistant Director Data Science Overview Polic...
# 18              Report Data Science Dept Contribute IP
# 19   Company Profile Morgan Stanley Firms Morgan St...
# 20        Dr Anupam Gupta at.anupamgupta1984 gmail.com
# 21   Job Purpose Thought ( Machine Learning AI ) As...
# 22   Institute High Performance Computing Institute...
# 23   Data Science Singapore Hadoop SQL Scalding Hiv...
# 24   Data Scientist Data Scientist Healthcare Infor...
# 25   Institute Media Innovation Nanyang Technologic...
# 26   Institute Media Innovation Nanyang Technologic...
# 27
# 28
# 29   ’ IT/Digital Data Analytics Microservices RPA ...
# ..                                                 ...
# 186  Agency Science Technology Research ( A*STAR ) ...
# 187  Have Data Science Palo IT Data Intelligence Re...
# 188       Job Purpose AI Machine Learning Grid Quality
# 189  SIA Enterprise Information Management ( EIM ) ...
# 190  AXA Group Insurance Asset Management AXA custo...
# 191  School Civil Environmental Engineering Nanyang...
# 192  Industry Internet This National Research Found...
# 193                                 API ( Python ) Use
# 194
# 195  Global Fashion Group Southeast Asia ICONIC Aus...
# 196  Daimler Financial Services Singapore Africa As...
# 197                                               Work
# 198  SCHOOL ELECTRICAL AND ELECTRONIC ENGINEERING (...
# 199  ) Capable Data Analytics Consumer Analytics Ap...
# 200  ) Capable Data Analytics Consumer Analytics Ap...
# 201                                              Peach
# 202  Data Scientist or.Data Analyst Scala Java C++ ...
# 203  Prospect Dentsu Aegis Network Incubatenew Mach...
# 204                                       Optimization
# 205  Client Company Byte Mod ( World Top Product Ma...
# 206        Client Company Byte Mod ( World Top Conduct
# 207  Client Company Byte Mod ( World Top Bytedance ...
# 208                        Robot Operating System Meet
# 209  Profile Design Thinking Agile approaches.Our I...
# 210  Smart Nation Digital Government Office ( SNDGO...
# 211  Development Smart Nation Health Tech Singapore...
# 212  BAF ( Data Analytics ) Data Analytics Work Per...
# 213  Technology-Enabled National Population Smart N...
# 214  R D Social Media Telco Telco Singapore Compute...
# 215  Job Responsibilities R D Data Analytics Artifi...
#
#                                     job_requirement_vb  \
# 0    be working Working authoring write is is be is...
# 1    be working Working authoring write is is be is...
# 2    qualify have is encouraged apply run managing ...
# 3    building been specialise interpret seek develo...
# 4    related work work are ) are include based be a...
# 5    are are looking manipulating processing extrac...
# 6    are share take going provide shaping conceptua...
# 7    have done have debugging have working have 've...
# 8    following Text applied asking answering distri...
# 9    following Text applied asking answering distri...
# 10                  Need are looking working messaging
# 11   be added working apply send updated resume be ...
# 12   experience is using analyzing writing collect ...
# 13                          have have is be is be work
# 14    related building building developing distributed
# 15   have based have architecting developing deploy...
# 16   is align interest stretch help grow impact lea...
# 17   be required leading collaborating work oversee...
# 18   Understanding Spark following processing be share
# 19   learn desired Existing including Search learn ...
# 20                         implementing master work be
# 21   meet link using building implementing ( – arti...
# 22                                 Science/Engineering
# 23                                           scripting
# 24   Let get excited have working learning includin...
# 25   hold have mentioned evidenced learning be spok...
# 26   hold have mentioned evidenced learning be spok...
# 27   Science/Engineering are include based be amend...
# 28   Science/Engineering are include based be amend...
# 29   have architecting solutioning involve have arc...
# ..                                                 ...
# 186  be preferred are include based be amended regr...
# 187  hold is required applied frameworks charting a...
# 188  working programing using Written Working embra...
# 189  is required related following working working ...
# 190  distributed processing building Understanding ...
# 191                                  work meet working
# 192  do have work offer develop implement following...
# 193                             work include…Languages
# 194  solving using applying working preferred shape...
# 195  Having Being Being Cassandra.Having working de...
# 196  versed applied Reduce recognize analyze develo...
# 197  is be enforce Having building is reduce has is...
# 198
# 199  are looking are want return qualified have app...
# 200  are looking are want return qualified have app...
# 201  designing developing learning emerging acquire...
# 202  possess mentioned possess solving is work mana...
# 203  marketing ( Click including Reduce developing ...
# 204                            Required is programming
# 205  working delivering travel needed shortlisted b...
# 206                     is set shortlisted be notified
# 207  work working working is preferred shortlisted ...
# 208  developing using pick build scoping teach develop
# 209  stack is required oriented including is deploying
# 210  are share take going provide shaping conceptua...
# 211  leading using test build architecting using wo...
# 212  be working take understand using using working...
# 213
# 214  be relating Text is is work involving is build...
# 215  s including visualization• communicate spoken ...
#
#                                     job_description_vb  latitude  longtitude  \
# 0    attract result has is empowered build using be...  1.300213  103.837286
# 1    attract result has is empowered build using be...  1.300213  103.837286
# 2    Join help work be aligned works experience tai...  1.280895  103.851677
# 3    is fosters drive transform .For please advance...  1.285407  103.850568
# 4                       Specialize applying be prepare  1.285407  103.850568
# 5    focuses creating is is delivering be built con...  1.279468  103.853750
# 6    plans prioritizes raises builds promotes takes...       NaN         NaN
# 7    be end use be be work examine analyze Pushing ...  1.275857  103.845955
# 8    support following discover interpret document ...  1.285407  103.850568
# 9    support following discover interpret document ...  1.285407  103.850568
# 10   develop create are assembled move deliver be i...  1.325516  103.872258
# 11   is holding are looking support learn get used ...  1.275857  103.845955
# 12   understand prioritize address Using scoop deve...  1.336050  103.889986
# 13   is aims create are consist Visiting be Perform...  1.346603  103.681356
# 14   is strives develop combined stack learning are...  1.285785  103.852220
# 15   please apply have heard going 's do is hiring ...  1.285407  103.850568
# 16   Impress loves solves fascinated wants learn bu...  1.352062  103.860698
# 17   advance leveraging drive lead delivering be do...  1.279331  103.838315
# 18   Get know Explore extract Build validate deploy...  1.276981  103.848409
# 19   is leading providing serve including is share ...  1.282288  103.852774
# 20   be come be implement compare existing get invo...  1.297245  103.781158
# 21   is provide meet deliver contribute heads under...  1.334132  103.965833
# 22   s was established provide seeks are please per...  1.285407  103.850568
# 23   are considering are based has understand accel...  1.283205  103.851910
# 24   are seeking join based Med focus use distribut...  1.380194  103.974116
# 25   invites leading include contribute leading bui...  1.346603  103.681356
# 26   invites leading include contribute leading bui...  1.346603  103.681356
# 27      perform applied learning including be involved  1.285407  103.850568
# 28      perform applied learning including be involved  1.285407  103.850568
# 29   Solves develop provide addressing build manage...  1.278941  103.851256
# ..                                                 ...       ...         ...
# 186  is that.fosters drive transform please control...  1.285407  103.850568
# 187  Thrive was failed Are learning are deal were s...  1.285894  103.849640
# 188  are looking join .focus moving be systemsinteg...  1.280919  103.848244
# 189  has implemented is is looking help continue bu...  1.377163  103.997294
# 190  supports advises meeting is expressed tailored...  1.275731  103.847220
# 191  is seeking Assist Modelling pertaining involve...  1.346603  103.681356
# 192  are looking aims associated exploit is using c...  1.303997  103.774033
# 193  Develop aims become existing written using Dev...  1.297245  103.781158
# 194  Develop address leveraging Engage identify sol...  1.296781  103.786757
# 195  is emerging operates employs is is guided cont...  1.274399  103.842261
# 196  is headquartered provides includes has are eng...  1.334599  103.742944
# 197  implement Ensure are defined optimize Keep be ...  1.290761  103.784855
# 198  Established is Built is renowned are is ranks ...  1.346603  103.681356
# 199  ( designing delivering Text applying are desig...  1.296862  103.852213
# 200  ( designing delivering Text applying are desig...  1.296862  103.852213
# 201  Interact define deliver existing solving encou...  1.335786  103.885510
# 202  build address Undertake Build involve crunchin...  1.273209  103.845282
# 203  helps develop support developing improve achie...  1.276800  103.845618
# 204  is expected design implement distinguish achie...  1.346603  103.681356
# 205  known founded is launch powered has been named...  1.278128  103.847855
# 206  known founded is launch powered has been named...  1.278128  103.847855
# 207  known founded is launch powered has been named...  1.278128  103.847855
# 208  is delivers are looking join provide be develo...  1.443384  103.836620
# 209  Create challenging apply solving is innovate b...  1.300213  103.837286
# 210  plans prioritizes raises builds promotes takes...  1.290592  103.849904
# 211  are seeking take leading using be provide guid...  1.274826  103.799074
# 212  are looking ( using help address stay be demon...  1.274826  103.799074
# 213  is endorsed involve collect matched create del...  1.279331  103.838315
# 214  are looking work focused related have integrat...  1.446272  103.783229
# 215  are looking work take designing developing sup...  1.446272  103.783229
#
#      job_experience             job_degree
# 0                 2               Bachelor
# 1                 2               Bachelor
# 2             eight
# 3                 5       Bachelor, Master
# 4                              Master, PhD
# 5                              Master, PhD
# 6                 2
# 7                 3                 Master
# 8                                 Bachelor
# 9                                 Bachelor
# 10
# 11                1       Bachelor, Master
# 12                                  Master
# 13                                Bachelor
# 14                3               Bachelor
# 15                5               Bachelor
# 16                   Bachelor, Master, PhD
# 17                5
# 18                3            Master, PhD
# 19                2
# 20                                  Master
# 21
# 22                                     PhD
# 23                   Bachelor, Master, PhD
# 24                             Master, PhD
# 25                                     PhD
# 26                                  Master
# 27                                     PhD
# 28                                     PhD
# 29
# ..              ...                    ...
# 186               2
# 187                  Bachelor, Master, PhD
# 188               2               Bachelor
# 189               3               Bachelor
# 190               4       Bachelor, Master
# 191               1                 Master
# 192                                    PhD
# 193               2
# 194                            Master, PhD
# 195               5            Master, PhD
# 196
# 197               3            Master, PhD
# 198                                 Master
# 199                            Master, PhD
# 200                            Master, PhD
# 201
# 202
# 203
# 204                               Bachelor
# 205            five               Bachelor
# 206               3               Bachelor
# 207               5               Bachelor
# 208
# 209               6               Bachelor
# 210               2
# 211                                Diploma
# 212               3        Master, Diploma
# 213
# 214
# 215                               Bachelor
#
# [216 rows x 22 columns]
